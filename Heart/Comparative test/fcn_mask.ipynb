# %%
# 导入必要的库
import SimpleITK as sitk
import matplotlib.pyplot as plt

# 设置文件路径
image_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0100/patient0100_4CH_ES.nii.gz'
mask_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0100/patient0100_4CH_ES_gt.nii.gz'

# 读取图像和掩膜
image = sitk.ReadImage(image_path)
mask = sitk.ReadImage(mask_path)

# 将SimpleITK图像转换为numpy数组
image_array = sitk.GetArrayFromImage(image)
mask_array = sitk.GetArrayFromImage(mask)

# 检查图像的维度
print(f"Image shape: {image_array.shape}")
print(f"Mask shape: {mask_array.shape}")

# 处理二维和三维的情况
if image_array.ndim == 3:
    # 如果是三维图像，选择中间切片
    slice_idx = image_array.shape[0] // 2
    image_slice = image_array[slice_idx, :, :]
    mask_slice = mask_array[slice_idx, :, :]
elif image_array.ndim == 2:
    # 如果是二维图像，直接显示
    image_slice = image_array
    mask_slice = mask_array
else:
    raise ValueError("Unsupported image dimensions.")

# 显示图像和掩膜
plt.figure(figsize=(12, 6))

# 显示图像
plt.subplot(1, 2, 1)
plt.imshow(image_slice, cmap='gray')
plt.title('Image Slice')
plt.axis('off')

# 显示掩膜
plt.subplot(1, 2, 2)
plt.imshow(mask_slice, cmap='gray')
plt.title('Mask Slice')
plt.axis('off')

# 显示图像
plt.show()
# Out:
# Image shape: (519, 630)
# Mask shape: (519, 630)

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# 加载原始图像和mask
image_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0400/patient0400_4CH_ES.nii.gz'
mask_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0400/patient0400_4CH_ES_gt.nii.gz'

# 使用nibabel加载NIfTI图像
image_data = nib.load(image_path).get_fdata()
mask_data = nib.load(mask_path).get_fdata()

# 打印图像数据的维度
print("Image Data Shape:", image_data.shape)
print("Mask Data Shape:", mask_data.shape)

# 查看mask的最小值和最大值
print("Mask Data Min:", np.min(mask_data))
print("Mask Data Max:", np.max(mask_data))

# 如果mask中有其他值（例如非0/1的标记），我们将其归一化为0和1
mask_data = np.where(mask_data > 0, 1, 0)

# 创建一个2x1的子图
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# 显示原始图像
ax[0].imshow(image_data, cmap='gray')
ax[0].set_title('Original Image')
ax[0].axis('off')

# 显示mask图像
ax[1].imshow(mask_data, cmap='gray')
ax[1].set_title('Mask')
ax[1].axis('off')

# 展示图像
plt.tight_layout()
plt.show()
# Out:
# Image Data Shape: (669, 552)
# Mask Data Shape: (669, 552)
# Mask Data Min: 0.0
# Mask Data Max: 3.0

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

# Load the original image and mask
image_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0002/patient0002_4CH_ES.nii.gz'
mask_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0002/patient0002_4CH_ES_gt.nii.gz'

# Use nibabel to load the NIfTI images
image_data = nib.load(image_path).get_fdata()
mask_data = nib.load(mask_path).get_fdata()

# Print the shape of the image data
print("Image Data Shape:", image_data.shape)
print("Mask Data Shape:", mask_data.shape)

# Check the minimum and maximum values of the mask
print("Mask Data Min:", np.min(mask_data))
print("Mask Data Max:", np.max(mask_data))

# Normalize the mask values to be 0 and 1
mask_data = np.where(mask_data > 0, 1, 0)

# Rotate both the image and the mask by 90 degrees clockwise
image_data_rotated = np.rot90(image_data, k=-1)  # Rotate 90 degrees clockwise
mask_data_rotated = np.rot90(mask_data, k=-1)  # Rotate 90 degrees clockwise

# Create a 2x1 subplot
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Display the rotated image
ax[0].imshow(image_data_rotated, cmap='gray')
ax[0].set_title('Original Image (Rotated)')
ax[0].axis('off')

# Display the rotated mask
ax[1].imshow(mask_data_rotated, cmap='gray')
ax[1].set_title('Mask (Rotated)')
ax[1].axis('off')

# Show the images
plt.tight_layout()
plt.show()
# Out:
# Image Data Shape: (748, 584)
# Mask Data Shape: (748, 584)
# Mask Data Min: 0.0
# Mask Data Max: 3.0

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import SimpleITK as sitk
from torchvision import transforms, models
import torch.nn.functional as F
from torch import amp
import torchvision.transforms.functional as TF
import nibabel as nib
import matplotlib.pyplot as plt

# 修改路径，确保能找到 echo.py
import sys
sys.path.append('/home/gem/wz/心脏/混合/单一')

# 导入 Echo 类
try:
    from echo import Echo
    print("Echo class imported successfully from /home/gem/wz/心脏/混合/单一.")
except ImportError as e:
    print(f"Error importing Echo: {e}")

# 提升 GPU 性能的设置
torch.backends.cudnn.benchmark = True  # 对于固定输入尺寸非常有用

# 数据预处理
both_transform = transforms.Compose([
    transforms.Resize((112, 112)),  # 将图像尺寸调整为112x112
    transforms.ToTensor(),
])

# 自定义 CAMUS 数据集类
class CAMUS_4CH_Dataset(Dataset):
    def __init__(self, data_dir, split='train'):
        self.data_dir = data_dir
        self.patients_list = sorted([x for x in os.listdir(data_dir) if (os.path.isdir(os.path.join(data_dir, x)) and x.startswith('patient'))])
        if split == 'train':
            self.patients_list = self.patients_list[:400]  # 训练集
        elif split == 'val':
            self.patients_list = self.patients_list[400:450]  # 验证集
        elif split == 'test':
            self.patients_list = self.patients_list[450:]  # 测试集

    def __len__(self):
        return len(self.patients_list)

    def __getitem__(self, index):
        patient_unique_id = str(self.patients_list[index])
        patient_dir = os.path.join(self.data_dir, patient_unique_id)
        image_path = os.path.join(patient_dir, patient_unique_id + "_4CH_ES.nii.gz")
        mask_path = os.path.join(patient_dir, patient_unique_id + "_4CH_ES_gt.nii.gz")

        image_file = sitk.GetArrayFromImage(sitk.ReadImage(image_path, sitk.sitkFloat32))
        mask_file = sitk.GetArrayFromImage(sitk.ReadImage(mask_path, sitk.sitkFloat32))

        mask_file[mask_file != 1] = 0
        mask_file[mask_file == 1] = 1.0

        if image_file.ndim == 2:
            image_file = np.expand_dims(image_file, axis=0)

        if image_file.shape[0] == 1:
            image_file = np.repeat(image_file, 3, axis=0)

        image_file = torch.from_numpy(image_file).float()
        mask_file = torch.from_numpy(np.expand_dims(mask_file, axis=0)).float()

        if image_file.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            image_file = TF.resize(image_file, [112, 112])
        if mask_file.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            mask_file = TF.resize(mask_file, [112, 112])

        image_file = image_file.view(3, 112, 112)  # 调整为112x112
        mask_file = mask_file.view(1, 112, 112)  # 调整为112x112

        return image_file, mask_file

# 自定义 Echo 数据集类
class EchoDataset(Dataset):
    def __init__(self, echo_data):
        self.echo_data = echo_data

    def __len__(self):
        return len(self.echo_data)

    def __getitem__(self, idx):
        image, mask = self.echo_data[idx]

        if isinstance(mask, tuple) and len(mask) == 2:
            large_trace = mask[0]
        else:
            raise ValueError("mask should be a tuple containing two elements.")

        mask_image = (large_trace > 0).astype(np.float32)

        if image.ndim == 4 and image.shape[1] > 1:
            image = image[:, 0, :, :]

        if image.ndim == 3:
            image = np.transpose(image, (2, 0, 1))
        elif image.ndim == 2:
            image = image[np.newaxis, ...]

        if mask_image.ndim == 3:
            mask_image = mask_image[0][np.newaxis, ...]

        image = torch.from_numpy(image).float()
        mask_image = torch.from_numpy(mask_image).float()

        if image.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            image = TF.resize(image, [112, 112])
        if mask_image.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            mask_image = TF.resize(mask_image, [112, 112])

        image = image.view(3, 112, 112)  # 调整为112x112
        mask_image = mask_image.view(1, 112, 112)  # 调整为112x112

        return image, mask_image

# 定义 CombinedDataset 将两个数据集组合
class CombinedDataset(Dataset):
    def __init__(self, camus_dataset, echo_dataset):
        self.camus_dataset = camus_dataset
        self.echo_dataset = echo_dataset
        self.total_len = len(camus_dataset) + len(echo_dataset)
    
    def __len__(self):
        return self.total_len
    
    def __getitem__(self, idx):
        if idx < len(self.camus_dataset):
            return self.camus_dataset[idx]
        else:
            return self.echo_dataset[idx - len(self.camus_dataset)]

# 使用混合精度训练以提高 GPU 效率
scaler = amp.GradScaler()  # 自动混合精度

# 定义分割指标
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred = torch.sigmoid(y_pred)
    y_pred = (y_pred > threshold).float()

    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)

    intersection = (y_true_f * y_pred_f).sum()
    dice = (2. * intersection + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

    union = y_true_f.sum() + y_pred_f.sum() - intersection
    iou = (intersection + smooth) / (union + smooth)

    tp = (y_true_f * y_pred_f).sum()
    fp = ((1 - y_true_f) * y_pred_f).sum()
    precision = (tp + smooth) / (tp + fp + smooth)

    fn = (y_true_f * (1 - y_pred_f)).sum()
    recall = (tp + smooth) / (tp + fn + smooth)

    tn = ((1 - y_true_f) * (1 - y_pred_f)).sum()
    accuracy = (tp + tn + smooth) / (y_true_f.size(0) + smooth)
    return dice.item(), iou.item(), precision.item(), recall.item(), accuracy.item()

# 验证函数
def validate(model, loader, criterion, device):
    model.eval()
    val_loss = 0.0
    dice_score = 0.0
    iou_score = 0.0
    precision_score = 0.0
    recall_score = 0.0
    accuracy_score = 0.0
    with torch.no_grad():
        for images, masks in loader:
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)
            
            with amp.autocast('cuda'):
                outputs = model(images)['out']
                loss = criterion(outputs, masks)
                val_loss += loss.item()
                
                dice, iou, precision, recall, accuracy = calculate_metrics(masks, outputs)
                dice_score += dice
                iou_score += iou
                precision_score += precision
                recall_score += recall
                accuracy_score += accuracy

    val_loss /= len(loader)
    metrics = {
        'loss': val_loss,
        'dice': dice_score / len(loader),
        'iou': iou_score / len(loader),
        'precision': precision_score / len(loader),
        'recall': recall_score / len(loader),
        'accuracy': accuracy_score / len(loader),
    }
    return metrics

# 训练函数
def train_model(model, train_loader, val_loader, test_loader, num_epochs=50, learning_rate=0.001, accumulation_steps=4):
    # 指定使用 GPU 3
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # 将模型移动到 GPU，使用所有可用的 GPU
    model = nn.DataParallel(model).to(device)
    
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

    scaler = amp.GradScaler('cuda')
    
    best_dice = 0.0  # 保存最佳Dice得分
    best_model_path = '/home/gem/wz/心脏/混合/权重/best_model_max.pth'

    print("开始训练...")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        dice_score = 0.0
        iou_score = 0.0
        precision_score = 0.0
        recall_score = 0.0
        accuracy_score = 0.0
        optimizer.zero_grad()

        for step, (images, masks) in enumerate(train_loader):
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)
            
            with amp.autocast('cuda'):
                outputs = model(images)['out']
                loss = criterion(outputs, masks) / accumulation_steps  # 梯度累积
            
            scaler.scale(loss).backward()
            
            if (step + 1) % accumulation_steps == 0:
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()

            running_loss += loss.item()
            dice, iou, precision, recall, accuracy = calculate_metrics(masks, outputs)
            dice_score += dice
            iou_score += iou
            precision_score += precision
            recall_score += recall
            accuracy_score += accuracy

        epoch_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Dice: {dice_score/len(train_loader):.4f}, IoU: {iou_score/len(train_loader):.4f}, Precision: {precision_score/len(train_loader):.4f}, Recall: {recall_score/len(train_loader):.4f}, Accuracy: {accuracy_score/len(train_loader):.4f}")
        
        # 验证集评估
        val_metrics = validate(model, val_loader, criterion, device)
        print(f"Validation Loss: {val_metrics['loss']:.4f}, Dice: {val_metrics['dice']:.4f}, IoU: {val_metrics['iou']:.4f}, Precision: {val_metrics['precision']:.4f}, Recall: {val_metrics['recall']:.4f}, Accuracy: {val_metrics['accuracy']:.4f}")
        
        # 保存最佳模型
        if val_metrics['dice'] > best_dice:
            best_dice = val_metrics['dice']
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved with Dice: {best_dice:.4f}")

    # 测试集评估
    print("开始测试...")
    test_metrics = validate(model, test_loader, criterion, device)
    print(f"Test Loss: {test_metrics['loss']:.4f}, IoU: {test_metrics['iou']:.4f}, Dice: {test_metrics['dice']:.4f}, Accuracy: {test_metrics['accuracy']:.4f}, Precision: {test_metrics['precision']:.4f}, Recall: {test_metrics['recall']:.4f}")

# 数据集路径
DATA_DIR_CAMUS = "/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti"
DATA_DIR_ECHO = "/home/gem/wz/心脏/EchoNet-Dynamic"

# 加载 EchoNet-Dynamic 数据集的完整数据
echo_data_all= Echo(
    root=DATA_DIR_ECHO,
    split="all",  # 加载所有数据
    target_type=["LargeFrame", "LargeTrace"],
    length=1,
    period=1,
    clips=1,
    pad=None,
    noise=None,
    mean=0,
    std=1,
)

# 将 Echo 数据集按照 6:2:2 划分为训练集、验证集和测试集
total_len = len(echo_data_all)
train_len = int(0.6 * total_len)
val_len = int(0.2 * total_len)
test_len = total_len - train_len - val_len

echo_train_data, echo_val_data, echo_test_data = random_split(echo_data_all, [train_len, val_len, test_len])

# 初始化 CAMUS 数据集
camus_train_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='train')
camus_val_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='val')
camus_test_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='test')  # 定义 CAMUS 的测试集

# 包装为 EchoDataset
echo_dataset_train = EchoDataset(echo_train_data)
echo_dataset_val = EchoDataset(echo_val_data)
echo_dataset_test = EchoDataset(echo_test_data)  # 定义 Echo 测试集

combined_dataset_train = CombinedDataset(camus_train_data, echo_dataset_train)
combined_dataset_val = CombinedDataset(camus_val_data, echo_dataset_val)
combined_dataset_test = CombinedDataset(camus_test_data, echo_dataset_test)  # 混合测试集

# 创建 DataLoader
batch_size = 1024  # 保持 batch size 不变
num_workers = 16  # 保持 num_workers 不变
pin_memory = True  # 加速数据从内存到 GPU 的传输

train_loader = DataLoader(combined_dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(combined_dataset_val, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(combined_dataset_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)  # 使用混合测试集

# 打印 CAMUS 和 Echo 数据集的训练集、验证集和测试集的样本数
print(f"CAMUS 训练集样本数: {len(camus_train_data)}")
print(f"CAMUS 验证集样本数: {len(camus_val_data)}")
print(f"Echo 训练集样本数: {len(echo_dataset_train)}")
print(f"Echo 验证集样本数: {len(echo_dataset_val)}")
print(f"Echo 测试集样本数: {len(echo_dataset_test)}")

# 打印组合后的训练集、验证集和测试集样本数
print(f"现在训练的训练集样本数: {len(train_loader.dataset)}")
print(f"现在训练的验证集样本数: {len(val_loader.dataset)}")
print(f"现在训练的测试集样本数: {len(test_loader.dataset)}")

# 使用 FCN 作为分割模型
model = models.segmentation.fcn_resnet50(pretrained=False, num_classes=1)  # 使用 FCN，不要预训练权重

# 创建模型并训练
train_model(model, train_loader, val_loader, test_loader, num_epochs=150)

# ========== 以下为新增的 “模型推理与可视化” 部分 ==========

# 指定训练时保存的最佳模型权重路径（与 train_model 中一致）
best_model_path = '/home/gem/wz/心脏/混合/权重/best_model_max.pth'

# 设置设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 将模型切换到评估模式，并加载权重
model = models.segmentation.fcn_resnet50(pretrained=False, num_classes=1)
model = nn.DataParallel(model).to(device)
model.load_state_dict(torch.load(best_model_path))
model.eval()

# 读取用于预测的 NIfTI 图像
image_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0002/patient0002_4CH_ES.nii.gz'

# 使用 nibabel 加载原始图像
image_data = nib.load(image_path).get_fdata()

# 打印一下形状信息（可选）
print("Image Data Shape:", image_data.shape)

# 将图像逆时针旋转 90 度（与给定示例代码的旋转一致）
image_data_rotated = np.rot90(image_data, k=-1)  # k=-1 表示顺时针90度实际效果

# 将旋转后的 2D 图像转换为 3 通道
if image_data_rotated.ndim == 2:
    img = np.expand_dims(image_data_rotated, axis=0)  # shape -> (1, H, W)
else:
    raise ValueError("Expected a 2D image array.")

if img.shape[0] == 1:
    img = np.repeat(img, 3, axis=0)  # shape -> (3, H, W)

# 转为 Torch Tensor 并调整为 float
img_tensor = torch.from_numpy(img).float()

# 如果尺寸不是 112x112，则进行 Resize
if img_tensor.shape[1:] != torch.Size([112, 112]):
    img_tensor = TF.resize(img_tensor, [112, 112])

# 调整形状为 (1, 3, 112, 112) 并移动到设备
img_tensor = img_tensor.view(1, 3, 112, 112).to(device)

# 预测
with torch.no_grad():
    output = model(img_tensor)['out']         # 输出 logits
    pred_mask = torch.sigmoid(output)         # Sigmoid 归一化到 [0,1]
    pred_mask = (pred_mask > 0.5).float()     # 二值化
    pred_mask_np = pred_mask.cpu().numpy()[0, 0, :, :]  # 转为 NumPy 数组, shape -> (112,112)

# 可视化：原始旋转图像 与 模型预测的 Mask
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 左侧：显示旋转后的原始单帧灰度图
axes[0].imshow(image_data_rotated, cmap='gray')
axes[0].set_title('Original Image (Rotated)')
axes[0].axis('off')

# 右侧：显示模型预测的分割 Mask
axes[1].imshow(pred_mask_np, cmap='gray')
axes[1].set_title('Predicted Mask')
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Echo class imported successfully from /home/gem/wz/心脏/混合/单一.
# CAMUS 训练集样本数: 400
# CAMUS 验证集样本数: 50
# Echo 训练集样本数: 6014
# Echo 验证集样本数: 2004
# Echo 测试集样本数: 2006
# 现在训练的训练集样本数: 6414
# 现在训练的验证集样本数: 2054
# 现在训练的测试集样本数: 2056
# /home/gem/wz/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/gem/wz/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 开始训练...
# Epoch 1/150, Loss: 0.2365, Dice: 0.5911, IoU: 0.4235, Precision: 0.6116, Recall: 0.5721, Accuracy: 0.5629
# Validation Loss: 4.2343, Dice: 0.7436, IoU: 0.5919, Precision: 0.5948, Recall: 0.9917, Accuracy: 0.6064
# Best model saved with Dice: 0.7436
# Epoch 2/150, Loss: 0.3140, Dice: 0.6471, IoU: 0.4793, Precision: 0.7241, Recall: 0.5895, Accuracy: 0.6490
# Validation Loss: 11.2340, Dice: 0.7534, IoU: 0.6044, Precision: 0.6183, Recall: 0.9640, Accuracy: 0.6369
# Best model saved with Dice: 0.7534
# Epoch 3/150, Loss: 0.2743, Dice: 0.6190, IoU: 0.4483, Precision: 0.7612, Recall: 0.5216, Accuracy: 0.6462
# Validation Loss: 16.8076, Dice: 0.8170, IoU: 0.6906, Precision: 0.7067, Recall: 0.9679, Accuracy: 0.7504
# Best model saved with Dice: 0.8170
# Epoch 4/150, Loss: 0.1918, Dice: 0.6177, IoU: 0.4470, Precision: 0.8270, Recall: 0.4960, Accuracy: 0.6631
# Validation Loss: 3.2366, Dice: 0.7991, IoU: 0.6655, Precision: 0.7709, Recall: 0.8296, Accuracy: 0.7599
# Epoch 5/150, Loss: 0.1336, Dice: 0.6727, IoU: 0.5124, Precision: 0.8829, Recall: 0.5518, Accuracy: 0.7128
# Validation Loss: 0.5721, Dice: 0.7447, IoU: 0.5932, Precision: 0.8523, Recall: 0.6613, Accuracy: 0.7390
# Epoch 6/150, Loss: 0.1128, Dice: 0.7975, IoU: 0.6641, Precision: 0.8583, Recall: 0.7482, Accuracy: 0.7920
# Validation Loss: 0.4776, Dice: 0.7954, IoU: 0.6605, Precision: 0.8545, Recall: 0.7441, Accuracy: 0.7800
# Epoch 7/150, Loss: 0.1033, Dice: 0.8366, IoU: 0.7192, Precision: 0.8336, Recall: 0.8399, Accuracy: 0.8190
# Validation Loss: 0.4221, Dice: 0.8382, IoU: 0.7215, Precision: 0.8328, Recall: 0.8439, Accuracy: 0.8126
# Best model saved with Dice: 0.8382
# Epoch 8/150, Loss: 0.0951, Dice: 0.8513, IoU: 0.7411, Precision: 0.8299, Recall: 0.8739, Accuracy: 0.8320
# Validation Loss: 0.3901, Dice: 0.8659, IoU: 0.7636, Precision: 0.8218, Recall: 0.9151, Accuracy: 0.8369
# Best model saved with Dice: 0.8659
# Epoch 9/150, Loss: 0.0877, Dice: 0.8608, IoU: 0.7556, Precision: 0.8352, Recall: 0.8880, Accuracy: 0.8422
# Validation Loss: 0.4131, Dice: 0.8672, IoU: 0.7655, Precision: 0.8134, Recall: 0.9286, Accuracy: 0.8363
# Best model saved with Dice: 0.8672
# Epoch 10/150, Loss: 0.0851, Dice: 0.8648, IoU: 0.7618, Precision: 0.8439, Recall: 0.8870, Accuracy: 0.8466
# Validation Loss: 0.3838, Dice: 0.8696, IoU: 0.7693, Precision: 0.8220, Recall: 0.9230, Accuracy: 0.8407
# Best model saved with Dice: 0.8696
# Epoch 11/150, Loss: 0.0832, Dice: 0.8680, IoU: 0.7668, Precision: 0.8432, Recall: 0.8943, Accuracy: 0.8504
# Validation Loss: 0.3494, Dice: 0.8719, IoU: 0.7728, Precision: 0.8335, Recall: 0.9140, Accuracy: 0.8454
# Best model saved with Dice: 0.8719
# Epoch 12/150, Loss: 0.0815, Dice: 0.8708, IoU: 0.7712, Precision: 0.8437, Recall: 0.8998, Accuracy: 0.8528
# Validation Loss: 0.3410, Dice: 0.8731, IoU: 0.7748, Precision: 0.8378, Recall: 0.9116, Accuracy: 0.8475
# Best model saved with Dice: 0.8731
# Epoch 13/150, Loss: 0.0803, Dice: 0.8721, IoU: 0.7732, Precision: 0.8419, Recall: 0.9045, Accuracy: 0.8535
# Validation Loss: 0.3393, Dice: 0.8718, IoU: 0.7728, Precision: 0.8274, Recall: 0.9214, Accuracy: 0.8440
# Epoch 14/150, Loss: 0.0790, Dice: 0.8727, IoU: 0.7741, Precision: 0.8393, Recall: 0.9089, Accuracy: 0.8534
# Validation Loss: 0.3298, Dice: 0.8742, IoU: 0.7765, Precision: 0.8271, Recall: 0.9269, Accuracy: 0.8464
# Best model saved with Dice: 0.8742
# Epoch 15/150, Loss: 0.0783, Dice: 0.8728, IoU: 0.7743, Precision: 0.8354, Recall: 0.9137, Accuracy: 0.8535
# Validation Loss: 0.3281, Dice: 0.8753, IoU: 0.7782, Precision: 0.8285, Recall: 0.9277, Accuracy: 0.8478
# Best model saved with Dice: 0.8753
# Epoch 16/150, Loss: 0.0778, Dice: 0.8730, IoU: 0.7746, Precision: 0.8357, Recall: 0.9137, Accuracy: 0.8537
# Validation Loss: 0.3233, Dice: 0.8745, IoU: 0.7770, Precision: 0.8313, Recall: 0.9226, Accuracy: 0.8476
# Epoch 17/150, Loss: 0.0767, Dice: 0.8742, IoU: 0.7766, Precision: 0.8395, Recall: 0.9120, Accuracy: 0.8554
# Validation Loss: 0.3187, Dice: 0.8760, IoU: 0.7793, Precision: 0.8376, Recall: 0.9181, Accuracy: 0.8503
# Best model saved with Dice: 0.8760
# Epoch 18/150, Loss: 0.0762, Dice: 0.8749, IoU: 0.7776, Precision: 0.8426, Recall: 0.9099, Accuracy: 0.8567
# Validation Loss: 0.3157, Dice: 0.8766, IoU: 0.7803, Precision: 0.8413, Recall: 0.9150, Accuracy: 0.8516
# Best model saved with Dice: 0.8766
# Epoch 19/150, Loss: 0.0756, Dice: 0.8768, IoU: 0.7806, Precision: 0.8465, Recall: 0.9092, Accuracy: 0.8594
# Validation Loss: 0.3118, Dice: 0.8785, IoU: 0.7834, Precision: 0.8514, Recall: 0.9075, Accuracy: 0.8556
# Best model saved with Dice: 0.8785
# Epoch 20/150, Loss: 0.0750, Dice: 0.8777, IoU: 0.7820, Precision: 0.8508, Recall: 0.9063, Accuracy: 0.8609
# Validation Loss: 0.3079, Dice: 0.8796, IoU: 0.7851, Precision: 0.8511, Recall: 0.9103, Accuracy: 0.8566
# Best model saved with Dice: 0.8796
# Epoch 21/150, Loss: 0.0745, Dice: 0.8780, IoU: 0.7826, Precision: 0.8541, Recall: 0.9033, Accuracy: 0.8619
# Validation Loss: 0.3081, Dice: 0.8792, IoU: 0.7845, Precision: 0.8555, Recall: 0.9044, Accuracy: 0.8570
# Epoch 22/150, Loss: 0.0738, Dice: 0.8785, IoU: 0.7833, Precision: 0.8581, Recall: 0.9000, Accuracy: 0.8628
# Validation Loss: 0.3078, Dice: 0.8769, IoU: 0.7808, Precision: 0.8597, Recall: 0.8948, Accuracy: 0.8553
# Epoch 23/150, Loss: 0.0738, Dice: 0.8778, IoU: 0.7823, Precision: 0.8582, Recall: 0.8984, Accuracy: 0.8625
# Validation Loss: 0.3102, Dice: 0.8776, IoU: 0.7819, Precision: 0.8568, Recall: 0.8995, Accuracy: 0.8555
# Epoch 24/150, Loss: 0.0731, Dice: 0.8793, IoU: 0.7846, Precision: 0.8602, Recall: 0.8993, Accuracy: 0.8638
# Validation Loss: 0.3036, Dice: 0.8794, IoU: 0.7847, Precision: 0.8600, Recall: 0.8997, Accuracy: 0.8579
# Epoch 25/150, Loss: 0.0728, Dice: 0.8803, IoU: 0.7862, Precision: 0.8607, Recall: 0.9009, Accuracy: 0.8645
# Validation Loss: 0.3030, Dice: 0.8796, IoU: 0.7851, Precision: 0.8633, Recall: 0.8965, Accuracy: 0.8587
# Epoch 26/150, Loss: 0.0720, Dice: 0.8815, IoU: 0.7880, Precision: 0.8585, Recall: 0.9057, Accuracy: 0.8658
# Validation Loss: 0.3027, Dice: 0.8802, IoU: 0.7860, Precision: 0.8554, Recall: 0.9067, Accuracy: 0.8578
# Best model saved with Dice: 0.8802
# Epoch 27/150, Loss: 0.0718, Dice: 0.8817, IoU: 0.7884, Precision: 0.8571, Recall: 0.9078, Accuracy: 0.8660
# Validation Loss: 0.2986, Dice: 0.8817, IoU: 0.7884, Precision: 0.8605, Recall: 0.9039, Accuracy: 0.8603
# Best model saved with Dice: 0.8817
# Epoch 28/150, Loss: 0.0716, Dice: 0.8821, IoU: 0.7891, Precision: 0.8578, Recall: 0.9079, Accuracy: 0.8661
# Validation Loss: 0.3014, Dice: 0.8803, IoU: 0.7862, Precision: 0.8573, Recall: 0.9045, Accuracy: 0.8583
# Epoch 29/150, Loss: 0.0715, Dice: 0.8816, IoU: 0.7883, Precision: 0.8566, Recall: 0.9082, Accuracy: 0.8660
# Validation Loss: 0.2965, Dice: 0.8817, IoU: 0.7885, Precision: 0.8623, Recall: 0.9020, Accuracy: 0.8607
# Best model saved with Dice: 0.8817
# Epoch 30/150, Loss: 0.0712, Dice: 0.8821, IoU: 0.7890, Precision: 0.8577, Recall: 0.9079, Accuracy: 0.8666
# Validation Loss: 0.3032, Dice: 0.8784, IoU: 0.7832, Precision: 0.8577, Recall: 0.9000, Accuracy: 0.8564
# Epoch 31/150, Loss: 0.0710, Dice: 0.8821, IoU: 0.7891, Precision: 0.8595, Recall: 0.9060, Accuracy: 0.8668
# Validation Loss: 0.2970, Dice: 0.8815, IoU: 0.7881, Precision: 0.8628, Recall: 0.9010, Accuracy: 0.8605
# Epoch 32/150, Loss: 0.0708, Dice: 0.8824, IoU: 0.7896, Precision: 0.8633, Recall: 0.9024, Accuracy: 0.8672
# Validation Loss: 0.2914, Dice: 0.8840, IoU: 0.7921, Precision: 0.8676, Recall: 0.9011, Accuracy: 0.8639
# Best model saved with Dice: 0.8840
# Epoch 33/150, Loss: 0.0704, Dice: 0.8826, IoU: 0.7899, Precision: 0.8624, Recall: 0.9039, Accuracy: 0.8680
# Validation Loss: 0.2945, Dice: 0.8808, IoU: 0.7870, Precision: 0.8716, Recall: 0.8902, Accuracy: 0.8612
# Epoch 34/150, Loss: 0.0701, Dice: 0.8833, IoU: 0.7909, Precision: 0.8661, Recall: 0.9012, Accuracy: 0.8684
# Validation Loss: 0.2956, Dice: 0.8804, IoU: 0.7863, Precision: 0.8680, Recall: 0.8932, Accuracy: 0.8602
# Epoch 35/150, Loss: 0.0698, Dice: 0.8832, IoU: 0.7908, Precision: 0.8651, Recall: 0.9021, Accuracy: 0.8688
# Validation Loss: 0.2964, Dice: 0.8804, IoU: 0.7863, Precision: 0.8656, Recall: 0.8957, Accuracy: 0.8598
# Epoch 36/150, Loss: 0.0695, Dice: 0.8840, IoU: 0.7922, Precision: 0.8668, Recall: 0.9020, Accuracy: 0.8696
# Validation Loss: 0.2889, Dice: 0.8836, IoU: 0.7915, Precision: 0.8719, Recall: 0.8957, Accuracy: 0.8642
# Epoch 37/150, Loss: 0.0693, Dice: 0.8840, IoU: 0.7922, Precision: 0.8667, Recall: 0.9021, Accuracy: 0.8698
# Validation Loss: 0.2861, Dice: 0.8849, IoU: 0.7935, Precision: 0.8720, Recall: 0.8982, Accuracy: 0.8655
# Best model saved with Dice: 0.8849
# Epoch 38/150, Loss: 0.0691, Dice: 0.8847, IoU: 0.7932, Precision: 0.8673, Recall: 0.9028, Accuracy: 0.8701
# Validation Loss: 0.2849, Dice: 0.8857, IoU: 0.7948, Precision: 0.8723, Recall: 0.8995, Accuracy: 0.8663
# Best model saved with Dice: 0.8857
# Epoch 39/150, Loss: 0.0688, Dice: 0.8850, IoU: 0.7937, Precision: 0.8676, Recall: 0.9031, Accuracy: 0.8707
# Validation Loss: 0.2903, Dice: 0.8837, IoU: 0.7916, Precision: 0.8660, Recall: 0.9021, Accuracy: 0.8632
# Epoch 40/150, Loss: 0.0686, Dice: 0.8855, IoU: 0.7946, Precision: 0.8687, Recall: 0.9030, Accuracy: 0.8711
# Validation Loss: 0.2881, Dice: 0.8837, IoU: 0.7917, Precision: 0.8675, Recall: 0.9005, Accuracy: 0.8635
# Epoch 41/150, Loss: 0.0688, Dice: 0.8853, IoU: 0.7942, Precision: 0.8679, Recall: 0.9034, Accuracy: 0.8707
# Validation Loss: 0.2841, Dice: 0.8865, IoU: 0.7962, Precision: 0.8719, Recall: 0.9017, Accuracy: 0.8672
# Best model saved with Dice: 0.8865
# Epoch 42/150, Loss: 0.0682, Dice: 0.8860, IoU: 0.7954, Precision: 0.8678, Recall: 0.9051, Accuracy: 0.8719
# Validation Loss: 0.2863, Dice: 0.8843, IoU: 0.7927, Precision: 0.8723, Recall: 0.8968, Accuracy: 0.8649
# Epoch 43/150, Loss: 0.0683, Dice: 0.8860, IoU: 0.7953, Precision: 0.8687, Recall: 0.9041, Accuracy: 0.8716
# Validation Loss: 0.2855, Dice: 0.8855, IoU: 0.7945, Precision: 0.8709, Recall: 0.9006, Accuracy: 0.8659
# Epoch 44/150, Loss: 0.0679, Dice: 0.8865, IoU: 0.7961, Precision: 0.8684, Recall: 0.9054, Accuracy: 0.8722
# Validation Loss: 0.2895, Dice: 0.8819, IoU: 0.7888, Precision: 0.8658, Recall: 0.8986, Accuracy: 0.8613
# Epoch 45/150, Loss: 0.0677, Dice: 0.8871, IoU: 0.7971, Precision: 0.8682, Recall: 0.9068, Accuracy: 0.8726
# Validation Loss: 0.2867, Dice: 0.8851, IoU: 0.7939, Precision: 0.8685, Recall: 0.9023, Accuracy: 0.8651
# Epoch 46/150, Loss: 0.0674, Dice: 0.8875, IoU: 0.7978, Precision: 0.8665, Recall: 0.9096, Accuracy: 0.8731
# Validation Loss: 0.2795, Dice: 0.8888, IoU: 0.7998, Precision: 0.8687, Recall: 0.9098, Accuracy: 0.8689
# Best model saved with Dice: 0.8888
# Epoch 47/150, Loss: 0.0676, Dice: 0.8877, IoU: 0.7981, Precision: 0.8665, Recall: 0.9101, Accuracy: 0.8729
# Validation Loss: 0.2831, Dice: 0.8865, IoU: 0.7961, Precision: 0.8680, Recall: 0.9058, Accuracy: 0.8664
# Epoch 48/150, Loss: 0.0673, Dice: 0.8880, IoU: 0.7985, Precision: 0.8671, Recall: 0.9099, Accuracy: 0.8732
# Validation Loss: 0.2851, Dice: 0.8845, IoU: 0.7930, Precision: 0.8669, Recall: 0.9029, Accuracy: 0.8642
# Epoch 49/150, Loss: 0.0672, Dice: 0.8876, IoU: 0.7978, Precision: 0.8658, Recall: 0.9104, Accuracy: 0.8734
# Validation Loss: 0.2817, Dice: 0.8870, IoU: 0.7969, Precision: 0.8669, Recall: 0.9079, Accuracy: 0.8667
# Epoch 50/150, Loss: 0.0670, Dice: 0.8876, IoU: 0.7980, Precision: 0.8675, Recall: 0.9087, Accuracy: 0.8734
# Validation Loss: 0.2871, Dice: 0.8846, IoU: 0.7931, Precision: 0.8671, Recall: 0.9029, Accuracy: 0.8643
# Epoch 51/150, Loss: 0.0671, Dice: 0.8874, IoU: 0.7976, Precision: 0.8678, Recall: 0.9080, Accuracy: 0.8737
# Validation Loss: 0.2800, Dice: 0.8879, IoU: 0.7984, Precision: 0.8691, Recall: 0.9075, Accuracy: 0.8680
# Epoch 52/150, Loss: 0.0669, Dice: 0.8882, IoU: 0.7988, Precision: 0.8694, Recall: 0.9078, Accuracy: 0.8741
# Validation Loss: 0.2807, Dice: 0.8870, IoU: 0.7969, Precision: 0.8717, Recall: 0.9028, Accuracy: 0.8675
# Epoch 53/150, Loss: 0.0666, Dice: 0.8889, IoU: 0.8000, Precision: 0.8712, Recall: 0.9073, Accuracy: 0.8748
# Validation Loss: 0.2818, Dice: 0.8866, IoU: 0.7963, Precision: 0.8754, Recall: 0.8982, Accuracy: 0.8677
# Epoch 54/150, Loss: 0.0661, Dice: 0.8894, IoU: 0.8008, Precision: 0.8713, Recall: 0.9082, Accuracy: 0.8755
# Validation Loss: 0.2767, Dice: 0.8897, IoU: 0.8014, Precision: 0.8728, Recall: 0.9074, Accuracy: 0.8706
# Best model saved with Dice: 0.8897
# Epoch 55/150, Loss: 0.0664, Dice: 0.8887, IoU: 0.7997, Precision: 0.8691, Recall: 0.9092, Accuracy: 0.8749
# Validation Loss: 0.2850, Dice: 0.8849, IoU: 0.7936, Precision: 0.8654, Recall: 0.9053, Accuracy: 0.8643
# Epoch 56/150, Loss: 0.0664, Dice: 0.8888, IoU: 0.7999, Precision: 0.8697, Recall: 0.9089, Accuracy: 0.8745
# Validation Loss: 0.2807, Dice: 0.8861, IoU: 0.7955, Precision: 0.8737, Recall: 0.8989, Accuracy: 0.8669
# Epoch 57/150, Loss: 0.0660, Dice: 0.8896, IoU: 0.8011, Precision: 0.8692, Recall: 0.9109, Accuracy: 0.8755
# Validation Loss: 0.2750, Dice: 0.8893, IoU: 0.8008, Precision: 0.8760, Recall: 0.9031, Accuracy: 0.8706
# Epoch 58/150, Loss: 0.0660, Dice: 0.8895, IoU: 0.8010, Precision: 0.8694, Recall: 0.9106, Accuracy: 0.8753
# Validation Loss: 0.2753, Dice: 0.8894, IoU: 0.8008, Precision: 0.8740, Recall: 0.9053, Accuracy: 0.8703
# Epoch 59/150, Loss: 0.0661, Dice: 0.8895, IoU: 0.8010, Precision: 0.8695, Recall: 0.9105, Accuracy: 0.8753
# Validation Loss: 0.2787, Dice: 0.8874, IoU: 0.7976, Precision: 0.8699, Recall: 0.9056, Accuracy: 0.8676
# Epoch 60/150, Loss: 0.0656, Dice: 0.8900, IoU: 0.8017, Precision: 0.8693, Recall: 0.9116, Accuracy: 0.8760
# Validation Loss: 0.2726, Dice: 0.8902, IoU: 0.8022, Precision: 0.8741, Recall: 0.9070, Accuracy: 0.8713
# Best model saved with Dice: 0.8902
# Epoch 61/150, Loss: 0.0657, Dice: 0.8898, IoU: 0.8014, Precision: 0.8708, Recall: 0.9096, Accuracy: 0.8758
# Validation Loss: 0.2762, Dice: 0.8884, IoU: 0.7991, Precision: 0.8730, Recall: 0.9042, Accuracy: 0.8691
# Epoch 62/150, Loss: 0.0654, Dice: 0.8901, IoU: 0.8019, Precision: 0.8717, Recall: 0.9092, Accuracy: 0.8762
# Validation Loss: 0.2744, Dice: 0.8894, IoU: 0.8009, Precision: 0.8743, Recall: 0.9051, Accuracy: 0.8704
# Epoch 63/150, Loss: 0.0652, Dice: 0.8904, IoU: 0.8024, Precision: 0.8717, Recall: 0.9099, Accuracy: 0.8766
# Validation Loss: 0.2727, Dice: 0.8902, IoU: 0.8022, Precision: 0.8735, Recall: 0.9077, Accuracy: 0.8711
# Epoch 64/150, Loss: 0.0653, Dice: 0.8905, IoU: 0.8027, Precision: 0.8720, Recall: 0.9100, Accuracy: 0.8765
# Validation Loss: 0.2779, Dice: 0.8878, IoU: 0.7983, Precision: 0.8662, Recall: 0.9106, Accuracy: 0.8674
# Epoch 65/150, Loss: 0.0651, Dice: 0.8909, IoU: 0.8032, Precision: 0.8718, Recall: 0.9108, Accuracy: 0.8769
# Validation Loss: 0.2759, Dice: 0.8890, IoU: 0.8002, Precision: 0.8675, Recall: 0.9116, Accuracy: 0.8689
# Epoch 66/150, Loss: 0.0652, Dice: 0.8906, IoU: 0.8027, Precision: 0.8715, Recall: 0.9104, Accuracy: 0.8765
# Validation Loss: 0.2724, Dice: 0.8903, IoU: 0.8022, Precision: 0.8702, Recall: 0.9113, Accuracy: 0.8706
# Best model saved with Dice: 0.8903
# Epoch 67/150, Loss: 0.0649, Dice: 0.8907, IoU: 0.8029, Precision: 0.8705, Recall: 0.9119, Accuracy: 0.8770
# Validation Loss: 0.2704, Dice: 0.8911, IoU: 0.8036, Precision: 0.8744, Recall: 0.9085, Accuracy: 0.8722
# Best model saved with Dice: 0.8911
# Epoch 68/150, Loss: 0.0651, Dice: 0.8908, IoU: 0.8031, Precision: 0.8717, Recall: 0.9107, Accuracy: 0.8769
# Validation Loss: 0.2754, Dice: 0.8893, IoU: 0.8006, Precision: 0.8713, Recall: 0.9080, Accuracy: 0.8698
# Epoch 69/150, Loss: 0.0647, Dice: 0.8910, IoU: 0.8035, Precision: 0.8726, Recall: 0.9103, Accuracy: 0.8775
# Validation Loss: 0.2753, Dice: 0.8892, IoU: 0.8005, Precision: 0.8713, Recall: 0.9077, Accuracy: 0.8697
# Epoch 70/150, Loss: 0.0647, Dice: 0.8911, IoU: 0.8036, Precision: 0.8733, Recall: 0.9096, Accuracy: 0.8774
# Validation Loss: 0.2687, Dice: 0.8918, IoU: 0.8048, Precision: 0.8777, Recall: 0.9065, Accuracy: 0.8734
# Best model saved with Dice: 0.8918
# Epoch 71/150, Loss: 0.0645, Dice: 0.8914, IoU: 0.8041, Precision: 0.8741, Recall: 0.9095, Accuracy: 0.8780
# Validation Loss: 0.2709, Dice: 0.8900, IoU: 0.8017, Precision: 0.8740, Recall: 0.9065, Accuracy: 0.8709
# Epoch 72/150, Loss: 0.0642, Dice: 0.8920, IoU: 0.8050, Precision: 0.8738, Recall: 0.9109, Accuracy: 0.8784
# Validation Loss: 0.2683, Dice: 0.8915, IoU: 0.8043, Precision: 0.8752, Recall: 0.9085, Accuracy: 0.8727
# Epoch 73/150, Loss: 0.0641, Dice: 0.8922, IoU: 0.8054, Precision: 0.8721, Recall: 0.9132, Accuracy: 0.8786
# Validation Loss: 0.2702, Dice: 0.8921, IoU: 0.8053, Precision: 0.8722, Recall: 0.9129, Accuracy: 0.8729
# Best model saved with Dice: 0.8921
# Epoch 74/150, Loss: 0.0641, Dice: 0.8921, IoU: 0.8051, Precision: 0.8712, Recall: 0.9139, Accuracy: 0.8784
# Validation Loss: 0.2740, Dice: 0.8891, IoU: 0.8004, Precision: 0.8701, Recall: 0.9090, Accuracy: 0.8694
# Epoch 75/150, Loss: 0.0645, Dice: 0.8916, IoU: 0.8043, Precision: 0.8725, Recall: 0.9115, Accuracy: 0.8775
# Validation Loss: 0.2724, Dice: 0.8900, IoU: 0.8019, Precision: 0.8764, Recall: 0.9041, Accuracy: 0.8714
# Epoch 76/150, Loss: 0.0643, Dice: 0.8920, IoU: 0.8050, Precision: 0.8733, Recall: 0.9114, Accuracy: 0.8781
# Validation Loss: 0.2696, Dice: 0.8905, IoU: 0.8026, Precision: 0.8736, Recall: 0.9081, Accuracy: 0.8714
# Epoch 77/150, Loss: 0.0640, Dice: 0.8923, IoU: 0.8056, Precision: 0.8736, Recall: 0.9119, Accuracy: 0.8787
# Validation Loss: 0.2711, Dice: 0.8906, IoU: 0.8028, Precision: 0.8708, Recall: 0.9114, Accuracy: 0.8711
# Epoch 78/150, Loss: 0.0641, Dice: 0.8920, IoU: 0.8051, Precision: 0.8738, Recall: 0.9111, Accuracy: 0.8784
# Validation Loss: 0.2700, Dice: 0.8904, IoU: 0.8024, Precision: 0.8804, Recall: 0.9007, Accuracy: 0.8723
# Epoch 79/150, Loss: 0.0638, Dice: 0.8924, IoU: 0.8058, Precision: 0.8740, Recall: 0.9117, Accuracy: 0.8791
# Validation Loss: 0.2728, Dice: 0.8901, IoU: 0.8020, Precision: 0.8751, Recall: 0.9057, Accuracy: 0.8712
# Epoch 80/150, Loss: 0.0637, Dice: 0.8926, IoU: 0.8060, Precision: 0.8755, Recall: 0.9104, Accuracy: 0.8793
# Validation Loss: 0.2695, Dice: 0.8911, IoU: 0.8036, Precision: 0.8717, Recall: 0.9114, Accuracy: 0.8717
# Epoch 81/150, Loss: 0.0636, Dice: 0.8928, IoU: 0.8064, Precision: 0.8745, Recall: 0.9119, Accuracy: 0.8794
# Validation Loss: 0.2707, Dice: 0.8906, IoU: 0.8028, Precision: 0.8763, Recall: 0.9054, Accuracy: 0.8720
# Epoch 82/150, Loss: 0.0637, Dice: 0.8929, IoU: 0.8065, Precision: 0.8727, Recall: 0.9141, Accuracy: 0.8794
# Validation Loss: 0.2676, Dice: 0.8926, IoU: 0.8060, Precision: 0.8725, Recall: 0.9136, Accuracy: 0.8734
# Best model saved with Dice: 0.8926
# Epoch 83/150, Loss: 0.0635, Dice: 0.8929, IoU: 0.8066, Precision: 0.8732, Recall: 0.9136, Accuracy: 0.8795
# Validation Loss: 0.2701, Dice: 0.8905, IoU: 0.8027, Precision: 0.8730, Recall: 0.9088, Accuracy: 0.8713
# Epoch 84/150, Loss: 0.0637, Dice: 0.8925, IoU: 0.8059, Precision: 0.8743, Recall: 0.9115, Accuracy: 0.8791
# Validation Loss: 0.2646, Dice: 0.8939, IoU: 0.8082, Precision: 0.8780, Recall: 0.9105, Accuracy: 0.8757
# Best model saved with Dice: 0.8939
# Epoch 85/150, Loss: 0.0632, Dice: 0.8932, IoU: 0.8070, Precision: 0.8760, Recall: 0.9111, Accuracy: 0.8803
# Validation Loss: 0.2701, Dice: 0.8911, IoU: 0.8036, Precision: 0.8714, Recall: 0.9116, Accuracy: 0.8716
# Epoch 86/150, Loss: 0.0634, Dice: 0.8932, IoU: 0.8071, Precision: 0.8768, Recall: 0.9103, Accuracy: 0.8799
# Validation Loss: 0.2705, Dice: 0.8912, IoU: 0.8037, Precision: 0.8813, Recall: 0.9013, Accuracy: 0.8733
# Epoch 87/150, Loss: 0.0634, Dice: 0.8935, IoU: 0.8074, Precision: 0.8765, Recall: 0.9111, Accuracy: 0.8800
# Validation Loss: 0.2763, Dice: 0.8887, IoU: 0.7997, Precision: 0.8738, Recall: 0.9040, Accuracy: 0.8695
# Epoch 88/150, Loss: 0.0634, Dice: 0.8932, IoU: 0.8070, Precision: 0.8763, Recall: 0.9107, Accuracy: 0.8798
# Validation Loss: 0.2690, Dice: 0.8909, IoU: 0.8033, Precision: 0.8684, Recall: 0.9147, Accuracy: 0.8710
# Epoch 89/150, Loss: 0.0631, Dice: 0.8935, IoU: 0.8076, Precision: 0.8754, Recall: 0.9125, Accuracy: 0.8803
# Validation Loss: 0.2683, Dice: 0.8932, IoU: 0.8070, Precision: 0.8781, Recall: 0.9090, Accuracy: 0.8749
# Epoch 90/150, Loss: 0.0631, Dice: 0.8936, IoU: 0.8077, Precision: 0.8745, Recall: 0.9136, Accuracy: 0.8803
# Validation Loss: 0.2725, Dice: 0.8890, IoU: 0.8002, Precision: 0.8694, Recall: 0.9095, Accuracy: 0.8691
# Epoch 91/150, Loss: 0.0633, Dice: 0.8930, IoU: 0.8067, Precision: 0.8750, Recall: 0.9117, Accuracy: 0.8795
# Validation Loss: 0.2674, Dice: 0.8921, IoU: 0.8051, Precision: 0.8751, Recall: 0.9097, Accuracy: 0.8732
# Epoch 92/150, Loss: 0.0631, Dice: 0.8938, IoU: 0.8080, Precision: 0.8768, Recall: 0.9115, Accuracy: 0.8803
# Validation Loss: 0.2662, Dice: 0.8933, IoU: 0.8071, Precision: 0.8767, Recall: 0.9106, Accuracy: 0.8747
# Epoch 93/150, Loss: 0.0628, Dice: 0.8938, IoU: 0.8079, Precision: 0.8761, Recall: 0.9121, Accuracy: 0.8809
# Validation Loss: 0.2703, Dice: 0.8918, IoU: 0.8047, Precision: 0.8687, Recall: 0.9161, Accuracy: 0.8719
# Epoch 94/150, Loss: 0.0631, Dice: 0.8932, IoU: 0.8070, Precision: 0.8746, Recall: 0.9127, Accuracy: 0.8803
# Validation Loss: 0.2622, Dice: 0.8949, IoU: 0.8099, Precision: 0.8810, Recall: 0.9094, Accuracy: 0.8771
# Best model saved with Dice: 0.8949
# Epoch 95/150, Loss: 0.0630, Dice: 0.8939, IoU: 0.8082, Precision: 0.8732, Recall: 0.9156, Accuracy: 0.8803
# Validation Loss: 0.2683, Dice: 0.8912, IoU: 0.8038, Precision: 0.8772, Recall: 0.9058, Accuracy: 0.8727
# Epoch 96/150, Loss: 0.0627, Dice: 0.8946, IoU: 0.8093, Precision: 0.8756, Recall: 0.9144, Accuracy: 0.8810
# Validation Loss: 0.2650, Dice: 0.8928, IoU: 0.8064, Precision: 0.8765, Recall: 0.9098, Accuracy: 0.8743
# Epoch 97/150, Loss: 0.0627, Dice: 0.8941, IoU: 0.8084, Precision: 0.8752, Recall: 0.9138, Accuracy: 0.8810
# Validation Loss: 0.2657, Dice: 0.8935, IoU: 0.8076, Precision: 0.8764, Recall: 0.9114, Accuracy: 0.8750
# Epoch 98/150, Loss: 0.0627, Dice: 0.8945, IoU: 0.8091, Precision: 0.8769, Recall: 0.9127, Accuracy: 0.8810
# Validation Loss: 0.2666, Dice: 0.8932, IoU: 0.8071, Precision: 0.8684, Recall: 0.9196, Accuracy: 0.8734
# Epoch 99/150, Loss: 0.0628, Dice: 0.8940, IoU: 0.8083, Precision: 0.8776, Recall: 0.9111, Accuracy: 0.8808
# Validation Loss: 0.2675, Dice: 0.8926, IoU: 0.8060, Precision: 0.8767, Recall: 0.9089, Accuracy: 0.8740
# Epoch 100/150, Loss: 0.0627, Dice: 0.8945, IoU: 0.8091, Precision: 0.8781, Recall: 0.9115, Accuracy: 0.8812
# Validation Loss: 0.2654, Dice: 0.8919, IoU: 0.8048, Precision: 0.8763, Recall: 0.9080, Accuracy: 0.8732
# Epoch 101/150, Loss: 0.0624, Dice: 0.8948, IoU: 0.8097, Precision: 0.8763, Recall: 0.9142, Accuracy: 0.8815
# Validation Loss: 0.2621, Dice: 0.8948, IoU: 0.8096, Precision: 0.8720, Recall: 0.9188, Accuracy: 0.8756
# Epoch 102/150, Loss: 0.0626, Dice: 0.8945, IoU: 0.8091, Precision: 0.8761, Recall: 0.9137, Accuracy: 0.8811
# Validation Loss: 0.2686, Dice: 0.8919, IoU: 0.8049, Precision: 0.8736, Recall: 0.9110, Accuracy: 0.8728
# Epoch 103/150, Loss: 0.0627, Dice: 0.8939, IoU: 0.8081, Precision: 0.8770, Recall: 0.9115, Accuracy: 0.8810
# Validation Loss: 0.2648, Dice: 0.8930, IoU: 0.8067, Precision: 0.8786, Recall: 0.9079, Accuracy: 0.8747
# Epoch 104/150, Loss: 0.0625, Dice: 0.8942, IoU: 0.8087, Precision: 0.8773, Recall: 0.9118, Accuracy: 0.8813
# Validation Loss: 0.2655, Dice: 0.8947, IoU: 0.8095, Precision: 0.8719, Recall: 0.9188, Accuracy: 0.8755
# Epoch 105/150, Loss: 0.0620, Dice: 0.8951, IoU: 0.8102, Precision: 0.8776, Recall: 0.9134, Accuracy: 0.8822
# Validation Loss: 0.2618, Dice: 0.8941, IoU: 0.8084, Precision: 0.8754, Recall: 0.9136, Accuracy: 0.8754
# Epoch 106/150, Loss: 0.0623, Dice: 0.8946, IoU: 0.8093, Precision: 0.8761, Recall: 0.9139, Accuracy: 0.8815
# Validation Loss: 0.2649, Dice: 0.8942, IoU: 0.8087, Precision: 0.8705, Recall: 0.9193, Accuracy: 0.8748
# Epoch 107/150, Loss: 0.0623, Dice: 0.8949, IoU: 0.8098, Precision: 0.8764, Recall: 0.9142, Accuracy: 0.8818
# Validation Loss: 0.2683, Dice: 0.8921, IoU: 0.8052, Precision: 0.8693, Recall: 0.9161, Accuracy: 0.8723
# Epoch 108/150, Loss: 0.0619, Dice: 0.8953, IoU: 0.8104, Precision: 0.8775, Recall: 0.9137, Accuracy: 0.8824
# Validation Loss: 0.2684, Dice: 0.8908, IoU: 0.8032, Precision: 0.8784, Recall: 0.9037, Accuracy: 0.8724
# Epoch 109/150, Loss: 0.0620, Dice: 0.8953, IoU: 0.8104, Precision: 0.8787, Recall: 0.9126, Accuracy: 0.8824
# Validation Loss: 0.2657, Dice: 0.8928, IoU: 0.8063, Precision: 0.8704, Recall: 0.9164, Accuracy: 0.8732
# Epoch 110/150, Loss: 0.0624, Dice: 0.8945, IoU: 0.8091, Precision: 0.8764, Recall: 0.9133, Accuracy: 0.8813
# Validation Loss: 0.2697, Dice: 0.8920, IoU: 0.8051, Precision: 0.8757, Recall: 0.9089, Accuracy: 0.8732
# Epoch 111/150, Loss: 0.0623, Dice: 0.8951, IoU: 0.8102, Precision: 0.8761, Recall: 0.9150, Accuracy: 0.8819
# Validation Loss: 0.2653, Dice: 0.8930, IoU: 0.8066, Precision: 0.8703, Recall: 0.9169, Accuracy: 0.8734
# Epoch 112/150, Loss: 0.0621, Dice: 0.8949, IoU: 0.8097, Precision: 0.8768, Recall: 0.9138, Accuracy: 0.8817
# Validation Loss: 0.2691, Dice: 0.8918, IoU: 0.8048, Precision: 0.8753, Recall: 0.9090, Accuracy: 0.8729
# Epoch 113/150, Loss: 0.0620, Dice: 0.8954, IoU: 0.8106, Precision: 0.8771, Recall: 0.9145, Accuracy: 0.8822
# Validation Loss: 0.2656, Dice: 0.8932, IoU: 0.8070, Precision: 0.8692, Recall: 0.9185, Accuracy: 0.8735
# Epoch 114/150, Loss: 0.0620, Dice: 0.8951, IoU: 0.8101, Precision: 0.8788, Recall: 0.9120, Accuracy: 0.8822
# Validation Loss: 0.2655, Dice: 0.8929, IoU: 0.8066, Precision: 0.8813, Recall: 0.9049, Accuracy: 0.8750
# Epoch 115/150, Loss: 0.0619, Dice: 0.8951, IoU: 0.8101, Precision: 0.8783, Recall: 0.9125, Accuracy: 0.8822
# Validation Loss: 0.2606, Dice: 0.8955, IoU: 0.8109, Precision: 0.8733, Recall: 0.9189, Accuracy: 0.8766
# Best model saved with Dice: 0.8955
# Epoch 116/150, Loss: 0.0619, Dice: 0.8950, IoU: 0.8099, Precision: 0.8779, Recall: 0.9128, Accuracy: 0.8821
# Validation Loss: 0.2610, Dice: 0.8951, IoU: 0.8101, Precision: 0.8790, Recall: 0.9119, Accuracy: 0.8770
# Epoch 117/150, Loss: 0.0619, Dice: 0.8952, IoU: 0.8102, Precision: 0.8765, Recall: 0.9147, Accuracy: 0.8822
# Validation Loss: 0.2653, Dice: 0.8929, IoU: 0.8065, Precision: 0.8786, Recall: 0.9077, Accuracy: 0.8746
# Epoch 118/150, Loss: 0.0618, Dice: 0.8953, IoU: 0.8105, Precision: 0.8786, Recall: 0.9127, Accuracy: 0.8824
# Validation Loss: 0.2619, Dice: 0.8938, IoU: 0.8080, Precision: 0.8789, Recall: 0.9093, Accuracy: 0.8756
# Epoch 119/150, Loss: 0.0620, Dice: 0.8947, IoU: 0.8095, Precision: 0.8776, Recall: 0.9125, Accuracy: 0.8818
# Validation Loss: 0.2634, Dice: 0.8938, IoU: 0.8080, Precision: 0.8759, Recall: 0.9124, Accuracy: 0.8751
# Epoch 120/150, Loss: 0.0616, Dice: 0.8957, IoU: 0.8111, Precision: 0.8769, Recall: 0.9153, Accuracy: 0.8826
# Validation Loss: 0.2640, Dice: 0.8948, IoU: 0.8096, Precision: 0.8646, Recall: 0.9272, Accuracy: 0.8744
# Epoch 121/150, Loss: 0.0618, Dice: 0.8957, IoU: 0.8111, Precision: 0.8786, Recall: 0.9135, Accuracy: 0.8824
# Validation Loss: 0.2624, Dice: 0.8945, IoU: 0.8092, Precision: 0.8716, Recall: 0.9187, Accuracy: 0.8753
# Epoch 122/150, Loss: 0.0616, Dice: 0.8952, IoU: 0.8104, Precision: 0.8773, Recall: 0.9140, Accuracy: 0.8826
# Validation Loss: 0.2599, Dice: 0.8957, IoU: 0.8110, Precision: 0.8786, Recall: 0.9134, Accuracy: 0.8775
# Best model saved with Dice: 0.8957
# Epoch 123/150, Loss: 0.0618, Dice: 0.8950, IoU: 0.8099, Precision: 0.8766, Recall: 0.9142, Accuracy: 0.8821
# Validation Loss: 0.2639, Dice: 0.8935, IoU: 0.8076, Precision: 0.8706, Recall: 0.9177, Accuracy: 0.8741
# Epoch 124/150, Loss: 0.0616, Dice: 0.8957, IoU: 0.8111, Precision: 0.8785, Recall: 0.9136, Accuracy: 0.8826
# Validation Loss: 0.2574, Dice: 0.8962, IoU: 0.8120, Precision: 0.8796, Recall: 0.9135, Accuracy: 0.8782
# Best model saved with Dice: 0.8962
# Epoch 125/150, Loss: 0.0614, Dice: 0.8961, IoU: 0.8117, Precision: 0.8790, Recall: 0.9138, Accuracy: 0.8831
# Validation Loss: 0.2614, Dice: 0.8947, IoU: 0.8095, Precision: 0.8748, Recall: 0.9156, Accuracy: 0.8760
# Epoch 126/150, Loss: 0.0620, Dice: 0.8948, IoU: 0.8096, Precision: 0.8762, Recall: 0.9142, Accuracy: 0.8816
# Validation Loss: 0.2620, Dice: 0.8946, IoU: 0.8093, Precision: 0.8831, Recall: 0.9064, Accuracy: 0.8771
# Epoch 127/150, Loss: 0.0617, Dice: 0.8954, IoU: 0.8106, Precision: 0.8770, Recall: 0.9146, Accuracy: 0.8824
# Validation Loss: 0.2637, Dice: 0.8927, IoU: 0.8062, Precision: 0.8703, Recall: 0.9162, Accuracy: 0.8731
# Epoch 128/150, Loss: 0.0619, Dice: 0.8949, IoU: 0.8098, Precision: 0.8792, Recall: 0.9112, Accuracy: 0.8819
# Validation Loss: 0.2701, Dice: 0.8911, IoU: 0.8036, Precision: 0.8767, Recall: 0.9060, Accuracy: 0.8724
# Epoch 129/150, Loss: 0.0619, Dice: 0.8951, IoU: 0.8101, Precision: 0.8792, Recall: 0.9116, Accuracy: 0.8820
# Validation Loss: 0.2662, Dice: 0.8926, IoU: 0.8060, Precision: 0.8762, Recall: 0.9096, Accuracy: 0.8739
# Epoch 130/150, Loss: 0.0615, Dice: 0.8956, IoU: 0.8109, Precision: 0.8791, Recall: 0.9127, Accuracy: 0.8828
# Validation Loss: 0.2604, Dice: 0.8947, IoU: 0.8094, Precision: 0.8820, Recall: 0.9078, Accuracy: 0.8770
# Epoch 131/150, Loss: 0.0615, Dice: 0.8958, IoU: 0.8112, Precision: 0.8776, Recall: 0.9148, Accuracy: 0.8828
# Validation Loss: 0.2630, Dice: 0.8942, IoU: 0.8086, Precision: 0.8684, Recall: 0.9216, Accuracy: 0.8744
# Epoch 132/150, Loss: 0.0616, Dice: 0.8954, IoU: 0.8106, Precision: 0.8798, Recall: 0.9116, Accuracy: 0.8825
# Validation Loss: 0.2629, Dice: 0.8937, IoU: 0.8078, Precision: 0.8779, Recall: 0.9100, Accuracy: 0.8753
# Epoch 133/150, Loss: 0.0614, Dice: 0.8959, IoU: 0.8114, Precision: 0.8793, Recall: 0.9131, Accuracy: 0.8831
# Validation Loss: 0.2610, Dice: 0.8946, IoU: 0.8093, Precision: 0.8760, Recall: 0.9140, Accuracy: 0.8760
# Epoch 134/150, Loss: 0.0613, Dice: 0.8958, IoU: 0.8113, Precision: 0.8785, Recall: 0.9139, Accuracy: 0.8828
# Validation Loss: 0.2618, Dice: 0.8942, IoU: 0.8087, Precision: 0.8705, Recall: 0.9193, Accuracy: 0.8747
# Epoch 135/150, Loss: 0.0612, Dice: 0.8963, IoU: 0.8121, Precision: 0.8785, Recall: 0.9149, Accuracy: 0.8832
# Validation Loss: 0.2622, Dice: 0.8949, IoU: 0.8098, Precision: 0.8794, Recall: 0.9110, Accuracy: 0.8768
# Epoch 136/150, Loss: 0.0612, Dice: 0.8962, IoU: 0.8119, Precision: 0.8799, Recall: 0.9131, Accuracy: 0.8834
# Validation Loss: 0.2557, Dice: 0.8967, IoU: 0.8127, Precision: 0.8791, Recall: 0.9150, Accuracy: 0.8786
# Best model saved with Dice: 0.8967
# Epoch 137/150, Loss: 0.0610, Dice: 0.8961, IoU: 0.8118, Precision: 0.8811, Recall: 0.9117, Accuracy: 0.8835
# Validation Loss: 0.2622, Dice: 0.8936, IoU: 0.8077, Precision: 0.8848, Recall: 0.9026, Accuracy: 0.8762
# Epoch 138/150, Loss: 0.0614, Dice: 0.8958, IoU: 0.8113, Precision: 0.8774, Recall: 0.9150, Accuracy: 0.8827
# Validation Loss: 0.2641, Dice: 0.8932, IoU: 0.8071, Precision: 0.8741, Recall: 0.9132, Accuracy: 0.8743
# Epoch 139/150, Loss: 0.0611, Dice: 0.8957, IoU: 0.8112, Precision: 0.8798, Recall: 0.9123, Accuracy: 0.8831
# Validation Loss: 0.2622, Dice: 0.8941, IoU: 0.8085, Precision: 0.8786, Recall: 0.9103, Accuracy: 0.8759
# Epoch 140/150, Loss: 0.0610, Dice: 0.8965, IoU: 0.8124, Precision: 0.8795, Recall: 0.9143, Accuracy: 0.8835
# Validation Loss: 0.2654, Dice: 0.8927, IoU: 0.8062, Precision: 0.8726, Recall: 0.9137, Accuracy: 0.8734
# Epoch 141/150, Loss: 0.0610, Dice: 0.8962, IoU: 0.8120, Precision: 0.8783, Recall: 0.9150, Accuracy: 0.8833
# Validation Loss: 0.2613, Dice: 0.8940, IoU: 0.8083, Precision: 0.8722, Recall: 0.9169, Accuracy: 0.8747
# Epoch 142/150, Loss: 0.0611, Dice: 0.8960, IoU: 0.8115, Precision: 0.8796, Recall: 0.9130, Accuracy: 0.8833
# Validation Loss: 0.2599, Dice: 0.8955, IoU: 0.8108, Precision: 0.8811, Recall: 0.9104, Accuracy: 0.8777
# Epoch 143/150, Loss: 0.0609, Dice: 0.8964, IoU: 0.8122, Precision: 0.8798, Recall: 0.9135, Accuracy: 0.8838
# Validation Loss: 0.2583, Dice: 0.8955, IoU: 0.8107, Precision: 0.8719, Recall: 0.9204, Accuracy: 0.8763
# Epoch 144/150, Loss: 0.0612, Dice: 0.8955, IoU: 0.8108, Precision: 0.8771, Recall: 0.9148, Accuracy: 0.8827
# Validation Loss: 0.2631, Dice: 0.8941, IoU: 0.8085, Precision: 0.8746, Recall: 0.9146, Accuracy: 0.8752
# Epoch 145/150, Loss: 0.0614, Dice: 0.8960, IoU: 0.8116, Precision: 0.8775, Recall: 0.9154, Accuracy: 0.8828
# Validation Loss: 0.2585, Dice: 0.8957, IoU: 0.8111, Precision: 0.8812, Recall: 0.9108, Accuracy: 0.8779
# Epoch 146/150, Loss: 0.0617, Dice: 0.8949, IoU: 0.8099, Precision: 0.8799, Recall: 0.9106, Accuracy: 0.8822
# Validation Loss: 0.2586, Dice: 0.8964, IoU: 0.8123, Precision: 0.8710, Recall: 0.9234, Accuracy: 0.8772
# Epoch 147/150, Loss: 0.0617, Dice: 0.8951, IoU: 0.8100, Precision: 0.8772, Recall: 0.9139, Accuracy: 0.8820
# Validation Loss: 0.2692, Dice: 0.8919, IoU: 0.8049, Precision: 0.8759, Recall: 0.9086, Accuracy: 0.8730
# Epoch 148/150, Loss: 0.0615, Dice: 0.8959, IoU: 0.8114, Precision: 0.8745, Recall: 0.9184, Accuracy: 0.8823
# Validation Loss: 0.2573, Dice: 0.8947, IoU: 0.8095, Precision: 0.8799, Recall: 0.9101, Accuracy: 0.8767
# Epoch 149/150, Loss: 0.0615, Dice: 0.8951, IoU: 0.8100, Precision: 0.8799, Recall: 0.9107, Accuracy: 0.8826
# Validation Loss: 0.2638, Dice: 0.8943, IoU: 0.8088, Precision: 0.8796, Recall: 0.9094, Accuracy: 0.8762
# Epoch 150/150, Loss: 0.0611, Dice: 0.8963, IoU: 0.8121, Precision: 0.8820, Recall: 0.9111, Accuracy: 0.8837
# Validation Loss: 0.2646, Dice: 0.8945, IoU: 0.8091, Precision: 0.8758, Recall: 0.9140, Accuracy: 0.8758
# 开始测试...
# Test Loss: 0.2536, IoU: 0.8151, Dice: 0.8981, Accuracy: 0.8804, Precision: 0.8831, Recall: 0.9136
# /tmp/ipykernel_3770218/810320515.py:350: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# Image Data Shape: (748, 584)

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn as nn
import torch.optim as optim
import SimpleITK as sitk
from torchvision import transforms, models
import torch.nn.functional as F
from torch import amp
import torchvision.transforms.functional as TF
import nibabel as nib
import matplotlib.pyplot as plt

# 修改路径，确保能找到 echo.py
import sys
sys.path.append('/home/gem/wz/心脏/混合/单一')

# 导入 Echo 类
try:
    from echo import Echo
    print("Echo class imported successfully from /home/gem/wz/心脏/混合/单一.")
except ImportError as e:
    print(f"Error importing Echo: {e}")

# 提升 GPU 性能的设置
torch.backends.cudnn.benchmark = True  # 对于固定输入尺寸非常有用

# 数据预处理
both_transform = transforms.Compose([
    transforms.Resize((112, 112)),  # 将图像尺寸调整为112x112
    transforms.ToTensor(),
])

# 自定义 CAMUS 数据集类
class CAMUS_4CH_Dataset(Dataset):
    def __init__(self, data_dir, split='train'):
        self.data_dir = data_dir
        self.patients_list = sorted([x for x in os.listdir(data_dir) if (os.path.isdir(os.path.join(data_dir, x)) and x.startswith('patient'))])
        if split == 'train':
            self.patients_list = self.patients_list[:400]  # 训练集
        elif split == 'val':
            self.patients_list = self.patients_list[400:450]  # 验证集
        elif split == 'test':
            self.patients_list = self.patients_list[450:]  # 测试集

    def __len__(self):
        return len(self.patients_list)

    def __getitem__(self, index):
        patient_unique_id = str(self.patients_list[index])
        patient_dir = os.path.join(self.data_dir, patient_unique_id)
        image_path = os.path.join(patient_dir, patient_unique_id + "_4CH_ES.nii.gz")
        mask_path = os.path.join(patient_dir, patient_unique_id + "_4CH_ES_gt.nii.gz")

        image_file = sitk.GetArrayFromImage(sitk.ReadImage(image_path, sitk.sitkFloat32))
        mask_file = sitk.GetArrayFromImage(sitk.ReadImage(mask_path, sitk.sitkFloat32))

        mask_file[mask_file != 1] = 0
        mask_file[mask_file == 1] = 1.0

        if image_file.ndim == 2:
            image_file = np.expand_dims(image_file, axis=0)

        if image_file.shape[0] == 1:
            image_file = np.repeat(image_file, 3, axis=0)

        image_file = torch.from_numpy(image_file).float()
        mask_file = torch.from_numpy(np.expand_dims(mask_file, axis=0)).float()

        if image_file.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            image_file = TF.resize(image_file, [112, 112])
        if mask_file.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            mask_file = TF.resize(mask_file, [112, 112])

        image_file = image_file.view(3, 112, 112)  # 调整为112x112
        mask_file = mask_file.view(1, 112, 112)  # 调整为112x112

        return image_file, mask_file

# 自定义 Echo 数据集类
class EchoDataset(Dataset):
    def __init__(self, echo_data):
        self.echo_data = echo_data

    def __len__(self):
        return len(self.echo_data)

    def __getitem__(self, idx):
        image, mask = self.echo_data[idx]

        if isinstance(mask, tuple) and len(mask) == 2:
            large_trace = mask[0]
        else:
            raise ValueError("mask should be a tuple containing two elements.")

        mask_image = (large_trace > 0).astype(np.float32)

        if image.ndim == 4 and image.shape[1] > 1:
            image = image[:, 0, :, :]

        if image.ndim == 3:
            image = np.transpose(image, (2, 0, 1))
        elif image.ndim == 2:
            image = image[np.newaxis, ...]

        if mask_image.ndim == 3:
            mask_image = mask_image[0][np.newaxis, ...]

        image = torch.from_numpy(image).float()
        mask_image = torch.from_numpy(mask_image).float()

        if image.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            image = TF.resize(image, [112, 112])
        if mask_image.shape[1:] != torch.Size([112, 112]):  # 修改为112x112
            mask_image = TF.resize(mask_image, [112, 112])

        image = image.view(3, 112, 112)  # 调整为112x112
        mask_image = mask_image.view(1, 112, 112)  # 调整为112x112

        return image, mask_image

# 定义 CombinedDataset 将两个数据集组合
class CombinedDataset(Dataset):
    def __init__(self, camus_dataset, echo_dataset):
        self.camus_dataset = camus_dataset
        self.echo_dataset = echo_dataset
        self.total_len = len(camus_dataset) + len(echo_dataset)
    
    def __len__(self):
        return self.total_len
    
    def __getitem__(self, idx):
        if idx < len(self.camus_dataset):
            return self.camus_dataset[idx]
        else:
            return self.echo_dataset[idx - len(self.camus_dataset)]

# 使用混合精度训练以提高 GPU 效率
scaler = amp.GradScaler()  # 自动混合精度

# 定义分割指标
def calculate_metrics(y_true, y_pred, threshold=0.5, smooth=1e-6):
    y_pred = torch.sigmoid(y_pred)
    y_pred = (y_pred > threshold).float()

    y_true_f = y_true.view(-1)
    y_pred_f = y_pred.view(-1)

    intersection = (y_true_f * y_pred_f).sum()
    dice = (2. * intersection + smooth) / (y_true_f.sum() + y_pred_f.sum() + smooth)

    union = y_true_f.sum() + y_pred_f.sum() - intersection
    iou = (intersection + smooth) / (union + smooth)

    tp = (y_true_f * y_pred_f).sum()
    fp = ((1 - y_true_f) * y_pred_f).sum()
    precision = (tp + smooth) / (tp + fp + smooth)

    fn = (y_true_f * (1 - y_pred_f)).sum()
    recall = (tp + smooth) / (tp + fn + smooth)

    tn = ((1 - y_true_f) * (1 - y_pred_f)).sum()
    accuracy = (tp + tn + smooth) / (y_true_f.size(0) + smooth)
    return dice.item(), iou.item(), precision.item(), recall.item(), accuracy.item()

# 验证函数
def validate(model, loader, criterion, device):
    model.eval()
    val_loss = 0.0
    dice_score = 0.0
    iou_score = 0.0
    precision_score = 0.0
    recall_score = 0.0
    accuracy_score = 0.0
    with torch.no_grad():
        for images, masks in loader:
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)
            
            with amp.autocast('cuda'):
                outputs = model(images)['out']
                loss = criterion(outputs, masks)
                val_loss += loss.item()
                
                dice, iou, precision, recall, accuracy = calculate_metrics(masks, outputs)
                dice_score += dice
                iou_score += iou
                precision_score += precision
                recall_score += recall
                accuracy_score += accuracy

    val_loss /= len(loader)
    metrics = {
        'loss': val_loss,
        'dice': dice_score / len(loader),
        'iou': iou_score / len(loader),
        'precision': precision_score / len(loader),
        'recall': recall_score / len(loader),
        'accuracy': accuracy_score / len(loader),
    }
    return metrics

# 训练函数
def train_model(model, train_loader, val_loader, test_loader, num_epochs=50, learning_rate=0.001, accumulation_steps=4):
    # 指定使用 GPU 3
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    
    # 将模型移动到 GPU，使用所有可用的 GPU
    model = nn.DataParallel(model).to(device)
    
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

    scaler = amp.GradScaler('cuda')
    
    best_dice = 0.0  # 保存最佳Dice得分
    best_model_path = '/home/gem/wz/心脏/混合/权重/best_model_max.pth'

    print("开始训练...")
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        dice_score = 0.0
        iou_score = 0.0
        precision_score = 0.0
        recall_score = 0.0
        accuracy_score = 0.0
        optimizer.zero_grad()

        for step, (images, masks) in enumerate(train_loader):
            images = images.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)
            
            with amp.autocast('cuda'):
                outputs = model(images)['out']
                loss = criterion(outputs, masks) / accumulation_steps  # 梯度累积
            
            scaler.scale(loss).backward()
            
            if (step + 1) % accumulation_steps == 0:
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad()

            running_loss += loss.item()
            dice, iou, precision, recall, accuracy = calculate_metrics(masks, outputs)
            dice_score += dice
            iou_score += iou
            precision_score += precision
            recall_score += recall
            accuracy_score += accuracy

        epoch_loss = running_loss / len(train_loader)
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Dice: {dice_score/len(train_loader):.4f}, IoU: {iou_score/len(train_loader):.4f}, Precision: {precision_score/len(train_loader):.4f}, Recall: {recall_score/len(train_loader):.4f}, Accuracy: {accuracy_score/len(train_loader):.4f}")
        
        # 验证集评估
        val_metrics = validate(model, val_loader, criterion, device)
        print(f"Validation Loss: {val_metrics['loss']:.4f}, Dice: {val_metrics['dice']:.4f}, IoU: {val_metrics['iou']:.4f}, Precision: {val_metrics['precision']:.4f}, Recall: {val_metrics['recall']:.4f}, Accuracy: {val_metrics['accuracy']:.4f}")
        
        # 保存最佳模型
        if val_metrics['dice'] > best_dice:
            best_dice = val_metrics['dice']
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved with Dice: {best_dice:.4f}")

    # 测试集评估
    print("开始测试...")
    test_metrics = validate(model, test_loader, criterion, device)
    print(f"Test Loss: {test_metrics['loss']:.4f}, IoU: {test_metrics['iou']:.4f}, Dice: {test_metrics['dice']:.4f}, Accuracy: {test_metrics['accuracy']:.4f}, Precision: {test_metrics['precision']:.4f}, Recall: {test_metrics['recall']:.4f}")

# 数据集路径
DATA_DIR_CAMUS = "/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti"
DATA_DIR_ECHO = "/home/gem/wz/心脏/EchoNet-Dynamic"

# 加载 EchoNet-Dynamic 数据集的完整数据
echo_data_all= Echo(
    root=DATA_DIR_ECHO,
    split="all",  # 加载所有数据
    target_type=["LargeFrame", "LargeTrace"],
    length=1,
    period=1,
    clips=1,
    pad=None,
    noise=None,
    mean=0,
    std=1,
)

# 将 Echo 数据集按照 6:2:2 划分为训练集、验证集和测试集
total_len = len(echo_data_all)
train_len = int(0.6 * total_len)
val_len = int(0.2 * total_len)
test_len = total_len - train_len - val_len

echo_train_data, echo_val_data, echo_test_data = random_split(echo_data_all, [train_len, val_len, test_len])

# 初始化 CAMUS 数据集
camus_train_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='train')
camus_val_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='val')
camus_test_data = CAMUS_4CH_Dataset(DATA_DIR_CAMUS, split='test')  # 定义 CAMUS 的测试集

# 包装为 EchoDataset
echo_dataset_train = EchoDataset(echo_train_data)
echo_dataset_val = EchoDataset(echo_val_data)
echo_dataset_test = EchoDataset(echo_test_data)  # 定义 Echo 测试集

combined_dataset_train = CombinedDataset(camus_train_data, echo_dataset_train)
combined_dataset_val = CombinedDataset(camus_val_data, echo_dataset_val)
combined_dataset_test = CombinedDataset(camus_test_data, echo_dataset_test)  # 混合测试集

# 创建 DataLoader
batch_size = 512  # 保持 batch size 不变
num_workers = 16  # 保持 num_workers 不变
pin_memory = True  # 加速数据从内存到 GPU 的传输

train_loader = DataLoader(combined_dataset_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(combined_dataset_val, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(combined_dataset_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)  # 使用混合测试集

# 打印 CAMUS 和 Echo 数据集的训练集、验证集和测试集的样本数
print(f"CAMUS 训练集样本数: {len(camus_train_data)}")
print(f"CAMUS 验证集样本数: {len(camus_val_data)}")
print(f"Echo 训练集样本数: {len(echo_dataset_train)}")
print(f"Echo 验证集样本数: {len(echo_dataset_val)}")
print(f"Echo 测试集样本数: {len(echo_dataset_test)}")

# 打印组合后的训练集、验证集和测试集样本数
print(f"现在训练的训练集样本数: {len(train_loader.dataset)}")
print(f"现在训练的验证集样本数: {len(val_loader.dataset)}")
print(f"现在训练的测试集样本数: {len(test_loader.dataset)}")

# 使用 FCN 作为分割模型
model = models.segmentation.fcn_resnet50(pretrained=False, num_classes=1)  # 使用 FCN，不要预训练权重

# 创建模型并训练
train_model(model, train_loader, val_loader, test_loader, num_epochs=150)

# ========== 以下为新增的 “模型推理与可视化” 部分 ==========

# 指定训练时保存的最佳模型权重路径（与 train_model 中一致）
best_model_path = '/home/gem/wz/心脏/混合/权重/best_model_max.pth'

# 设置设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 将模型切换到评估模式，并加载权重
model = models.segmentation.fcn_resnet50(pretrained=False, num_classes=1)
model = nn.DataParallel(model).to(device)
model.load_state_dict(torch.load(best_model_path))
model.eval()

# 读取用于预测的 NIfTI 图像
image_path = '/home/gem/wz/心脏/CAMUS_public/CAMUS_public/database_nifti/patient0100/patient0100_4CH_ES.nii.gz'

# 使用 nibabel 加载原始图像
image_data = nib.load(image_path).get_fdata()

# 打印一下形状信息（可选）
print("Image Data Shape:", image_data.shape)

# 将图像逆时针旋转 90 度（与给定示例代码的旋转一致）
image_data_rotated = np.rot90(image_data, k=-1)  # k=-1 表示顺时针90度实际效果

# 将旋转后的 2D 图像转换为 3 通道
if image_data_rotated.ndim == 2:
    img = np.expand_dims(image_data_rotated, axis=0)  # shape -> (1, H, W)
else:
    raise ValueError("Expected a 2D image array.")

if img.shape[0] == 1:
    img = np.repeat(img, 3, axis=0)  # shape -> (3, H, W)

# 转为 Torch Tensor 并调整为 float
img_tensor = torch.from_numpy(img).float()

# 如果尺寸不是 112x112，则进行 Resize
if img_tensor.shape[1:] != torch.Size([112, 112]):
    img_tensor = TF.resize(img_tensor, [112, 112])

# 调整形状为 (1, 3, 112, 112) 并移动到设备
img_tensor = img_tensor.view(1, 3, 112, 112).to(device)

# 预测
with torch.no_grad():
    output = model(img_tensor)['out']         # 输出 logits
    pred_mask = torch.sigmoid(output)         # Sigmoid 归一化到 [0,1]
    pred_mask = (pred_mask > 0.5).float()     # 二值化
    pred_mask_np = pred_mask.cpu().numpy()[0, 0, :, :]  # 转为 NumPy 数组, shape -> (112,112)

# 可视化：原始旋转图像 与 模型预测的 Mask
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 左侧：显示旋转后的原始单帧灰度图
axes[0].imshow(image_data_rotated, cmap='gray')
axes[0].set_title('Original Image (Rotated)')
axes[0].axis('off')

# 右侧：显示模型预测的分割 Mask
axes[1].imshow(pred_mask_np, cmap='gray')
axes[1].set_title('Predicted Mask')
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Echo class imported successfully from /home/gem/wz/心脏/混合/单一.
# CAMUS 训练集样本数: 400
# CAMUS 验证集样本数: 50
# Echo 训练集样本数: 6014
# Echo 验证集样本数: 2004
# Echo 测试集样本数: 2006
# 现在训练的训练集样本数: 6414
# 现在训练的验证集样本数: 2054
# 现在训练的测试集样本数: 2056
# /home/gem/wz/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/gem/wz/.conda/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# 开始训练...
# Epoch 1/150, Loss: 0.2867, Dice: 0.5914, IoU: 0.4209, Precision: 0.6784, Recall: 0.5264, Accuracy: 0.6003
# Validation Loss: 35.7586, Dice: 0.7938, IoU: 0.6585, Precision: 0.6913, Recall: 0.9327, Accuracy: 0.7274
# Best model saved with Dice: 0.7938
# Epoch 2/150, Loss: 0.1489, Dice: 0.7180, IoU: 0.5626, Precision: 0.8667, Recall: 0.6154, Accuracy: 0.7370
# Validation Loss: 0.8336, Dice: 0.8084, IoU: 0.6785, Precision: 0.7604, Recall: 0.8640, Accuracy: 0.7692
# Best model saved with Dice: 0.8084
# Epoch 3/150, Loss: 0.0958, Dice: 0.8447, IoU: 0.7314, Precision: 0.8397, Recall: 0.8513, Accuracy: 0.8285
# Validation Loss: 0.3973, Dice: 0.8450, IoU: 0.7320, Precision: 0.8264, Recall: 0.8644, Accuracy: 0.8218
# Best model saved with Dice: 0.8450
# Epoch 4/150, Loss: 0.0823, Dice: 0.8667, IoU: 0.7648, Precision: 0.8332, Recall: 0.9031, Accuracy: 0.8474
# Validation Loss: 0.4426, Dice: 0.8529, IoU: 0.7437, Precision: 0.8072, Recall: 0.9043, Accuracy: 0.8245
# Best model saved with Dice: 0.8529
# Epoch 5/150, Loss: 0.0786, Dice: 0.8725, IoU: 0.7738, Precision: 0.8380, Recall: 0.9099, Accuracy: 0.8538
# Validation Loss: 0.3567, Dice: 0.8622, IoU: 0.7580, Precision: 0.8354, Recall: 0.8907, Accuracy: 0.8399
# Best model saved with Dice: 0.8622
# Epoch 6/150, Loss: 0.0758, Dice: 0.8742, IoU: 0.7764, Precision: 0.8501, Recall: 0.8997, Accuracy: 0.8575
# Validation Loss: 0.3217, Dice: 0.8664, IoU: 0.7645, Precision: 0.8602, Recall: 0.8728, Accuracy: 0.8487
# Best model saved with Dice: 0.8664
# Epoch 7/150, Loss: 0.0739, Dice: 0.8762, IoU: 0.7797, Precision: 0.8592, Recall: 0.8939, Accuracy: 0.8612
# Validation Loss: 0.3057, Dice: 0.8726, IoU: 0.7741, Precision: 0.8668, Recall: 0.8785, Accuracy: 0.8557
# Best model saved with Dice: 0.8726
# Epoch 8/150, Loss: 0.0726, Dice: 0.8803, IoU: 0.7862, Precision: 0.8601, Recall: 0.9015, Accuracy: 0.8651
# Validation Loss: 0.3028, Dice: 0.8765, IoU: 0.7803, Precision: 0.8635, Recall: 0.8900, Accuracy: 0.8589
# Best model saved with Dice: 0.8765
# Epoch 9/150, Loss: 0.0715, Dice: 0.8821, IoU: 0.7891, Precision: 0.8613, Recall: 0.9040, Accuracy: 0.8672
# Validation Loss: 0.2978, Dice: 0.8778, IoU: 0.7825, Precision: 0.8677, Recall: 0.8883, Accuracy: 0.8610
# Best model saved with Dice: 0.8778
# Epoch 10/150, Loss: 0.0703, Dice: 0.8838, IoU: 0.7918, Precision: 0.8633, Recall: 0.9053, Accuracy: 0.8691
# Validation Loss: 0.2953, Dice: 0.8786, IoU: 0.7836, Precision: 0.8723, Recall: 0.8850, Accuracy: 0.8625
# Best model saved with Dice: 0.8786
# Epoch 11/150, Loss: 0.0697, Dice: 0.8844, IoU: 0.7928, Precision: 0.8658, Recall: 0.9039, Accuracy: 0.8701
# Validation Loss: 0.2928, Dice: 0.8787, IoU: 0.7840, Precision: 0.8767, Recall: 0.8811, Accuracy: 0.8635
# Best model saved with Dice: 0.8787
# Epoch 12/150, Loss: 0.0689, Dice: 0.8858, IoU: 0.7950, Precision: 0.8655, Recall: 0.9071, Accuracy: 0.8715
# Validation Loss: 0.2881, Dice: 0.8828, IoU: 0.7903, Precision: 0.8645, Recall: 0.9018, Accuracy: 0.8652
# Best model saved with Dice: 0.8828
# Epoch 13/150, Loss: 0.0683, Dice: 0.8866, IoU: 0.7963, Precision: 0.8667, Recall: 0.9076, Accuracy: 0.8724
# Validation Loss: 0.2878, Dice: 0.8821, IoU: 0.7892, Precision: 0.8690, Recall: 0.8955, Accuracy: 0.8654
# Epoch 14/150, Loss: 0.0680, Dice: 0.8870, IoU: 0.7969, Precision: 0.8686, Recall: 0.9061, Accuracy: 0.8730
# Validation Loss: 0.2847, Dice: 0.8829, IoU: 0.7906, Precision: 0.8672, Recall: 0.8993, Accuracy: 0.8659
# Best model saved with Dice: 0.8829
# Epoch 15/150, Loss: 0.0674, Dice: 0.8875, IoU: 0.7978, Precision: 0.8676, Recall: 0.9084, Accuracy: 0.8735
# Validation Loss: 0.2837, Dice: 0.8840, IoU: 0.7923, Precision: 0.8643, Recall: 0.9047, Accuracy: 0.8665
# Best model saved with Dice: 0.8840
# Epoch 16/150, Loss: 0.0670, Dice: 0.8882, IoU: 0.7989, Precision: 0.8678, Recall: 0.9096, Accuracy: 0.8741
# Validation Loss: 0.2818, Dice: 0.8846, IoU: 0.7933, Precision: 0.8689, Recall: 0.9010, Accuracy: 0.8678
# Best model saved with Dice: 0.8846
# Epoch 17/150, Loss: 0.0667, Dice: 0.8884, IoU: 0.7992, Precision: 0.8694, Recall: 0.9083, Accuracy: 0.8745
# Validation Loss: 0.2808, Dice: 0.8839, IoU: 0.7922, Precision: 0.8741, Recall: 0.8941, Accuracy: 0.8681
# Epoch 18/150, Loss: 0.0662, Dice: 0.8891, IoU: 0.8003, Precision: 0.8699, Recall: 0.9091, Accuracy: 0.8753
# Validation Loss: 0.2779, Dice: 0.8865, IoU: 0.7962, Precision: 0.8688, Recall: 0.9048, Accuracy: 0.8696
# Best model saved with Dice: 0.8865
# Epoch 19/150, Loss: 0.0660, Dice: 0.8895, IoU: 0.8009, Precision: 0.8692, Recall: 0.9107, Accuracy: 0.8757
# Validation Loss: 0.2773, Dice: 0.8858, IoU: 0.7952, Precision: 0.8666, Recall: 0.9059, Accuracy: 0.8687
# Epoch 20/150, Loss: 0.0654, Dice: 0.8903, IoU: 0.8022, Precision: 0.8698, Recall: 0.9118, Accuracy: 0.8765
# Validation Loss: 0.2786, Dice: 0.8851, IoU: 0.7940, Precision: 0.8690, Recall: 0.9018, Accuracy: 0.8684
# Epoch 21/150, Loss: 0.0653, Dice: 0.8902, IoU: 0.8022, Precision: 0.8728, Recall: 0.9084, Accuracy: 0.8768
# Validation Loss: 0.2756, Dice: 0.8867, IoU: 0.7966, Precision: 0.8761, Recall: 0.8976, Accuracy: 0.8710
# Best model saved with Dice: 0.8867
# Epoch 22/150, Loss: 0.0650, Dice: 0.8908, IoU: 0.8032, Precision: 0.8707, Recall: 0.9120, Accuracy: 0.8772
# Validation Loss: 0.2756, Dice: 0.8859, IoU: 0.7953, Precision: 0.8720, Recall: 0.9002, Accuracy: 0.8696
# Epoch 23/150, Loss: 0.0648, Dice: 0.8911, IoU: 0.8036, Precision: 0.8730, Recall: 0.9100, Accuracy: 0.8777
# Validation Loss: 0.2753, Dice: 0.8868, IoU: 0.7968, Precision: 0.8720, Recall: 0.9021, Accuracy: 0.8704
# Best model saved with Dice: 0.8868
# Epoch 24/150, Loss: 0.0644, Dice: 0.8918, IoU: 0.8047, Precision: 0.8716, Recall: 0.9130, Accuracy: 0.8783
# Validation Loss: 0.2716, Dice: 0.8884, IoU: 0.7993, Precision: 0.8690, Recall: 0.9087, Accuracy: 0.8715
# Best model saved with Dice: 0.8884
# Epoch 25/150, Loss: 0.0642, Dice: 0.8920, IoU: 0.8051, Precision: 0.8734, Recall: 0.9115, Accuracy: 0.8787
# Validation Loss: 0.2717, Dice: 0.8878, IoU: 0.7985, Precision: 0.8676, Recall: 0.9091, Accuracy: 0.8708
# Epoch 26/150, Loss: 0.0640, Dice: 0.8923, IoU: 0.8056, Precision: 0.8731, Recall: 0.9124, Accuracy: 0.8789
# Validation Loss: 0.2737, Dice: 0.8855, IoU: 0.7948, Precision: 0.8796, Recall: 0.8917, Accuracy: 0.8705
# Epoch 27/150, Loss: 0.0640, Dice: 0.8924, IoU: 0.8057, Precision: 0.8738, Recall: 0.9118, Accuracy: 0.8791
# Validation Loss: 0.2699, Dice: 0.8890, IoU: 0.8002, Precision: 0.8693, Recall: 0.9095, Accuracy: 0.8721
# Best model saved with Dice: 0.8890
# Epoch 28/150, Loss: 0.0635, Dice: 0.8931, IoU: 0.8068, Precision: 0.8743, Recall: 0.9127, Accuracy: 0.8798
# Validation Loss: 0.2713, Dice: 0.8879, IoU: 0.7986, Precision: 0.8727, Recall: 0.9036, Accuracy: 0.8717
# Epoch 29/150, Loss: 0.0634, Dice: 0.8930, IoU: 0.8068, Precision: 0.8756, Recall: 0.9112, Accuracy: 0.8801
# Validation Loss: 0.2706, Dice: 0.8877, IoU: 0.7983, Precision: 0.8738, Recall: 0.9021, Accuracy: 0.8717
# Epoch 30/150, Loss: 0.0632, Dice: 0.8934, IoU: 0.8074, Precision: 0.8753, Recall: 0.9123, Accuracy: 0.8803
# Validation Loss: 0.2694, Dice: 0.8892, IoU: 0.8006, Precision: 0.8656, Recall: 0.9140, Accuracy: 0.8718
# Best model saved with Dice: 0.8892
# Epoch 31/150, Loss: 0.0630, Dice: 0.8936, IoU: 0.8077, Precision: 0.8764, Recall: 0.9115, Accuracy: 0.8808
# Validation Loss: 0.2674, Dice: 0.8894, IoU: 0.8009, Precision: 0.8788, Recall: 0.9002, Accuracy: 0.8740
# Best model saved with Dice: 0.8894
# Epoch 32/150, Loss: 0.0629, Dice: 0.8938, IoU: 0.8080, Precision: 0.8758, Recall: 0.9126, Accuracy: 0.8808
# Validation Loss: 0.2681, Dice: 0.8903, IoU: 0.8023, Precision: 0.8685, Recall: 0.9131, Accuracy: 0.8733
# Best model saved with Dice: 0.8903
# Epoch 33/150, Loss: 0.0627, Dice: 0.8939, IoU: 0.8082, Precision: 0.8745, Recall: 0.9142, Accuracy: 0.8809
# Validation Loss: 0.2665, Dice: 0.8894, IoU: 0.8009, Precision: 0.8788, Recall: 0.9003, Accuracy: 0.8740
# Epoch 34/150, Loss: 0.0627, Dice: 0.8940, IoU: 0.8082, Precision: 0.8761, Recall: 0.9126, Accuracy: 0.8810
# Validation Loss: 0.2669, Dice: 0.8903, IoU: 0.8024, Precision: 0.8717, Recall: 0.9097, Accuracy: 0.8739
# Best model saved with Dice: 0.8903
# Epoch 35/150, Loss: 0.0623, Dice: 0.8943, IoU: 0.8089, Precision: 0.8784, Recall: 0.9109, Accuracy: 0.8817
# Validation Loss: 0.2663, Dice: 0.8911, IoU: 0.8037, Precision: 0.8719, Recall: 0.9112, Accuracy: 0.8746
# Best model saved with Dice: 0.8911
# Epoch 36/150, Loss: 0.0623, Dice: 0.8945, IoU: 0.8091, Precision: 0.8768, Recall: 0.9128, Accuracy: 0.8815
# Validation Loss: 0.2692, Dice: 0.8884, IoU: 0.7994, Precision: 0.8698, Recall: 0.9078, Accuracy: 0.8718
# Epoch 37/150, Loss: 0.0624, Dice: 0.8944, IoU: 0.8090, Precision: 0.8764, Recall: 0.9131, Accuracy: 0.8815
# Validation Loss: 0.2689, Dice: 0.8886, IoU: 0.7998, Precision: 0.8699, Recall: 0.9082, Accuracy: 0.8720
# Epoch 38/150, Loss: 0.0623, Dice: 0.8942, IoU: 0.8087, Precision: 0.8764, Recall: 0.9128, Accuracy: 0.8813
# Validation Loss: 0.2673, Dice: 0.8897, IoU: 0.8015, Precision: 0.8695, Recall: 0.9109, Accuracy: 0.8730
# Epoch 39/150, Loss: 0.0621, Dice: 0.8944, IoU: 0.8090, Precision: 0.8771, Recall: 0.9125, Accuracy: 0.8816
# Validation Loss: 0.2677, Dice: 0.8905, IoU: 0.8028, Precision: 0.8748, Recall: 0.9069, Accuracy: 0.8746
# Epoch 40/150, Loss: 0.0621, Dice: 0.8946, IoU: 0.8093, Precision: 0.8760, Recall: 0.9142, Accuracy: 0.8817
# Validation Loss: 0.2667, Dice: 0.8893, IoU: 0.8008, Precision: 0.8792, Recall: 0.8996, Accuracy: 0.8740
# Epoch 41/150, Loss: 0.0621, Dice: 0.8946, IoU: 0.8094, Precision: 0.8769, Recall: 0.9132, Accuracy: 0.8818
# Validation Loss: 0.2652, Dice: 0.8907, IoU: 0.8031, Precision: 0.8668, Recall: 0.9160, Accuracy: 0.8736
# Epoch 42/150, Loss: 0.0619, Dice: 0.8949, IoU: 0.8098, Precision: 0.8762, Recall: 0.9144, Accuracy: 0.8820
# Validation Loss: 0.2634, Dice: 0.8905, IoU: 0.8027, Precision: 0.8743, Recall: 0.9073, Accuracy: 0.8745
# Epoch 43/150, Loss: 0.0616, Dice: 0.8951, IoU: 0.8101, Precision: 0.8777, Recall: 0.9133, Accuracy: 0.8824
# Validation Loss: 0.2655, Dice: 0.8890, IoU: 0.8004, Precision: 0.8811, Recall: 0.8971, Accuracy: 0.8741
# Epoch 44/150, Loss: 0.0616, Dice: 0.8952, IoU: 0.8103, Precision: 0.8777, Recall: 0.9135, Accuracy: 0.8826
# Validation Loss: 0.2633, Dice: 0.8906, IoU: 0.8030, Precision: 0.8778, Recall: 0.9039, Accuracy: 0.8751
# Epoch 45/150, Loss: 0.0615, Dice: 0.8954, IoU: 0.8106, Precision: 0.8786, Recall: 0.9128, Accuracy: 0.8828
# Validation Loss: 0.2660, Dice: 0.8893, IoU: 0.8009, Precision: 0.8749, Recall: 0.9042, Accuracy: 0.8734
# Epoch 46/150, Loss: 0.0614, Dice: 0.8952, IoU: 0.8104, Precision: 0.8783, Recall: 0.9129, Accuracy: 0.8826
# Validation Loss: 0.2621, Dice: 0.8903, IoU: 0.8024, Precision: 0.8795, Recall: 0.9014, Accuracy: 0.8751
# Epoch 47/150, Loss: 0.0612, Dice: 0.8959, IoU: 0.8114, Precision: 0.8780, Recall: 0.9146, Accuracy: 0.8832
# Validation Loss: 0.2603, Dice: 0.8921, IoU: 0.8054, Precision: 0.8777, Recall: 0.9071, Accuracy: 0.8766
# Best model saved with Dice: 0.8921
# Epoch 48/150, Loss: 0.0614, Dice: 0.8956, IoU: 0.8109, Precision: 0.8771, Recall: 0.9150, Accuracy: 0.8828
# Validation Loss: 0.2623, Dice: 0.8907, IoU: 0.8031, Precision: 0.8710, Recall: 0.9113, Accuracy: 0.8742
# Epoch 49/150, Loss: 0.0614, Dice: 0.8952, IoU: 0.8104, Precision: 0.8792, Recall: 0.9120, Accuracy: 0.8827
# Validation Loss: 0.2632, Dice: 0.8895, IoU: 0.8011, Precision: 0.8795, Recall: 0.8997, Accuracy: 0.8742
# Epoch 50/150, Loss: 0.0612, Dice: 0.8955, IoU: 0.8108, Precision: 0.8791, Recall: 0.9125, Accuracy: 0.8830
# Validation Loss: 0.2643, Dice: 0.8886, IoU: 0.7997, Precision: 0.8848, Recall: 0.8925, Accuracy: 0.8742
# Epoch 51/150, Loss: 0.0612, Dice: 0.8957, IoU: 0.8112, Precision: 0.8770, Recall: 0.9153, Accuracy: 0.8830
# Validation Loss: 0.2632, Dice: 0.8921, IoU: 0.8053, Precision: 0.8697, Recall: 0.9156, Accuracy: 0.8753
# Epoch 52/150, Loss: 0.0610, Dice: 0.8960, IoU: 0.8116, Precision: 0.8794, Recall: 0.9132, Accuracy: 0.8834
# Validation Loss: 0.2620, Dice: 0.8921, IoU: 0.8053, Precision: 0.8675, Recall: 0.9182, Accuracy: 0.8750
# Epoch 53/150, Loss: 0.0609, Dice: 0.8961, IoU: 0.8118, Precision: 0.8787, Recall: 0.9142, Accuracy: 0.8836
# Validation Loss: 0.2620, Dice: 0.8913, IoU: 0.8041, Precision: 0.8775, Recall: 0.9056, Accuracy: 0.8758
# Epoch 54/150, Loss: 0.0610, Dice: 0.8961, IoU: 0.8117, Precision: 0.8776, Recall: 0.9155, Accuracy: 0.8833
# Validation Loss: 0.2655, Dice: 0.8891, IoU: 0.8005, Precision: 0.8777, Recall: 0.9009, Accuracy: 0.8736
# Epoch 55/150, Loss: 0.0612, Dice: 0.8953, IoU: 0.8105, Precision: 0.8801, Recall: 0.9111, Accuracy: 0.8830
# Validation Loss: 0.2584, Dice: 0.8928, IoU: 0.8065, Precision: 0.8738, Recall: 0.9126, Accuracy: 0.8767
# Best model saved with Dice: 0.8928
# Epoch 56/150, Loss: 0.0609, Dice: 0.8960, IoU: 0.8117, Precision: 0.8798, Recall: 0.9129, Accuracy: 0.8835
# Validation Loss: 0.2625, Dice: 0.8908, IoU: 0.8032, Precision: 0.8758, Recall: 0.9063, Accuracy: 0.8751
# Epoch 57/150, Loss: 0.0609, Dice: 0.8962, IoU: 0.8120, Precision: 0.8790, Recall: 0.9142, Accuracy: 0.8836
# Validation Loss: 0.2617, Dice: 0.8914, IoU: 0.8042, Precision: 0.8716, Recall: 0.9122, Accuracy: 0.8750
# Epoch 58/150, Loss: 0.0605, Dice: 0.8966, IoU: 0.8125, Precision: 0.8789, Recall: 0.9150, Accuracy: 0.8841
# Validation Loss: 0.2596, Dice: 0.8921, IoU: 0.8053, Precision: 0.8740, Recall: 0.9109, Accuracy: 0.8760
# Epoch 59/150, Loss: 0.0604, Dice: 0.8969, IoU: 0.8130, Precision: 0.8789, Recall: 0.9156, Accuracy: 0.8843
# Validation Loss: 0.2611, Dice: 0.8905, IoU: 0.8028, Precision: 0.8801, Recall: 0.9012, Accuracy: 0.8754
# Epoch 60/150, Loss: 0.0604, Dice: 0.8966, IoU: 0.8126, Precision: 0.8803, Recall: 0.9136, Accuracy: 0.8842
# Validation Loss: 0.2615, Dice: 0.8903, IoU: 0.8025, Precision: 0.8714, Recall: 0.9101, Accuracy: 0.8740
# Epoch 61/150, Loss: 0.0603, Dice: 0.8969, IoU: 0.8130, Precision: 0.8791, Recall: 0.9154, Accuracy: 0.8844
# Validation Loss: 0.2593, Dice: 0.8916, IoU: 0.8045, Precision: 0.8782, Recall: 0.9054, Accuracy: 0.8761
# Epoch 62/150, Loss: 0.0605, Dice: 0.8965, IoU: 0.8124, Precision: 0.8795, Recall: 0.9141, Accuracy: 0.8841
# Validation Loss: 0.2635, Dice: 0.8913, IoU: 0.8040, Precision: 0.8677, Recall: 0.9162, Accuracy: 0.8743
# Epoch 63/150, Loss: 0.0606, Dice: 0.8963, IoU: 0.8122, Precision: 0.8778, Recall: 0.9158, Accuracy: 0.8836
# Validation Loss: 0.2624, Dice: 0.8896, IoU: 0.8014, Precision: 0.8765, Recall: 0.9033, Accuracy: 0.8741
# Epoch 64/150, Loss: 0.0607, Dice: 0.8962, IoU: 0.8119, Precision: 0.8795, Recall: 0.9136, Accuracy: 0.8837
# Validation Loss: 0.2610, Dice: 0.8924, IoU: 0.8059, Precision: 0.8744, Recall: 0.9113, Accuracy: 0.8764
# Epoch 65/150, Loss: 0.0603, Dice: 0.8970, IoU: 0.8133, Precision: 0.8801, Recall: 0.9147, Accuracy: 0.8847
# Validation Loss: 0.2602, Dice: 0.8922, IoU: 0.8056, Precision: 0.8768, Recall: 0.9082, Accuracy: 0.8766
# Epoch 66/150, Loss: 0.0601, Dice: 0.8972, IoU: 0.8136, Precision: 0.8820, Recall: 0.9129, Accuracy: 0.8849
# Validation Loss: 0.2639, Dice: 0.8889, IoU: 0.8003, Precision: 0.8815, Recall: 0.8965, Accuracy: 0.8741
# Epoch 67/150, Loss: 0.0605, Dice: 0.8965, IoU: 0.8124, Precision: 0.8786, Recall: 0.9153, Accuracy: 0.8839
# Validation Loss: 0.2618, Dice: 0.8903, IoU: 0.8024, Precision: 0.8784, Recall: 0.9026, Accuracy: 0.8749
# Epoch 68/150, Loss: 0.0604, Dice: 0.8967, IoU: 0.8127, Precision: 0.8804, Recall: 0.9136, Accuracy: 0.8843
# Validation Loss: 0.2636, Dice: 0.8885, IoU: 0.7995, Precision: 0.8851, Recall: 0.8919, Accuracy: 0.8740
# Epoch 69/150, Loss: 0.0605, Dice: 0.8963, IoU: 0.8121, Precision: 0.8789, Recall: 0.9146, Accuracy: 0.8838
# Validation Loss: 0.2619, Dice: 0.8902, IoU: 0.8023, Precision: 0.8792, Recall: 0.9014, Accuracy: 0.8750
# Epoch 70/150, Loss: 0.0604, Dice: 0.8968, IoU: 0.8130, Precision: 0.8799, Recall: 0.9147, Accuracy: 0.8844
# Validation Loss: 0.2616, Dice: 0.8891, IoU: 0.8005, Precision: 0.8857, Recall: 0.8926, Accuracy: 0.8748
# Epoch 71/150, Loss: 0.0603, Dice: 0.8966, IoU: 0.8127, Precision: 0.8806, Recall: 0.9135, Accuracy: 0.8844
# Validation Loss: 0.2604, Dice: 0.8906, IoU: 0.8029, Precision: 0.8786, Recall: 0.9030, Accuracy: 0.8753
# Epoch 72/150, Loss: 0.0599, Dice: 0.8973, IoU: 0.8137, Precision: 0.8813, Recall: 0.9140, Accuracy: 0.8851
# Validation Loss: 0.2618, Dice: 0.8893, IoU: 0.8009, Precision: 0.8825, Recall: 0.8963, Accuracy: 0.8746
# Epoch 73/150, Loss: 0.0597, Dice: 0.8975, IoU: 0.8141, Precision: 0.8819, Recall: 0.9138, Accuracy: 0.8853
# Validation Loss: 0.2621, Dice: 0.8905, IoU: 0.8029, Precision: 0.8763, Recall: 0.9053, Accuracy: 0.8748
# Epoch 74/150, Loss: 0.0598, Dice: 0.8975, IoU: 0.8141, Precision: 0.8804, Recall: 0.9153, Accuracy: 0.8851
# Validation Loss: 0.2614, Dice: 0.8909, IoU: 0.8035, Precision: 0.8710, Recall: 0.9118, Accuracy: 0.8745
# Epoch 75/150, Loss: 0.0595, Dice: 0.8980, IoU: 0.8149, Precision: 0.8815, Recall: 0.9151, Accuracy: 0.8858
# Validation Loss: 0.2600, Dice: 0.8908, IoU: 0.8032, Precision: 0.8801, Recall: 0.9017, Accuracy: 0.8756
# Epoch 76/150, Loss: 0.0599, Dice: 0.8975, IoU: 0.8141, Precision: 0.8796, Recall: 0.9163, Accuracy: 0.8850
# Validation Loss: 0.2658, Dice: 0.8880, IoU: 0.7989, Precision: 0.8776, Recall: 0.8987, Accuracy: 0.8726
# Epoch 77/150, Loss: 0.0602, Dice: 0.8967, IoU: 0.8128, Precision: 0.8814, Recall: 0.9126, Accuracy: 0.8846
# Validation Loss: 0.2625, Dice: 0.8884, IoU: 0.7995, Precision: 0.8859, Recall: 0.8911, Accuracy: 0.8743
# Epoch 78/150, Loss: 0.0597, Dice: 0.8978, IoU: 0.8146, Precision: 0.8805, Recall: 0.9160, Accuracy: 0.8856
# Validation Loss: 0.2600, Dice: 0.8915, IoU: 0.8044, Precision: 0.8774, Recall: 0.9061, Accuracy: 0.8760
# Epoch 79/150, Loss: 0.0596, Dice: 0.8979, IoU: 0.8147, Precision: 0.8813, Recall: 0.9151, Accuracy: 0.8856
# Validation Loss: 0.2606, Dice: 0.8902, IoU: 0.8024, Precision: 0.8831, Recall: 0.8975, Accuracy: 0.8755
# Epoch 80/150, Loss: 0.0595, Dice: 0.8983, IoU: 0.8153, Precision: 0.8820, Recall: 0.9152, Accuracy: 0.8860
# Validation Loss: 0.2593, Dice: 0.8920, IoU: 0.8052, Precision: 0.8741, Recall: 0.9106, Accuracy: 0.8759
# Epoch 81/150, Loss: 0.0594, Dice: 0.8979, IoU: 0.8148, Precision: 0.8814, Recall: 0.9152, Accuracy: 0.8858
# Validation Loss: 0.2614, Dice: 0.8910, IoU: 0.8037, Precision: 0.8802, Recall: 0.9022, Accuracy: 0.8759
# Epoch 82/150, Loss: 0.0596, Dice: 0.8979, IoU: 0.8147, Precision: 0.8809, Recall: 0.9156, Accuracy: 0.8857
# Validation Loss: 0.2648, Dice: 0.8890, IoU: 0.8004, Precision: 0.8748, Recall: 0.9038, Accuracy: 0.8732
# Epoch 83/150, Loss: 0.0599, Dice: 0.8976, IoU: 0.8143, Precision: 0.8811, Recall: 0.9148, Accuracy: 0.8853
# Validation Loss: 0.2651, Dice: 0.8877, IoU: 0.7984, Precision: 0.8816, Recall: 0.8942, Accuracy: 0.8731
# Epoch 84/150, Loss: 0.0595, Dice: 0.8982, IoU: 0.8152, Precision: 0.8804, Recall: 0.9167, Accuracy: 0.8859
# Validation Loss: 0.2661, Dice: 0.8874, IoU: 0.7979, Precision: 0.8804, Recall: 0.8946, Accuracy: 0.8724
# Epoch 85/150, Loss: 0.0595, Dice: 0.8981, IoU: 0.8151, Precision: 0.8820, Recall: 0.9149, Accuracy: 0.8861
# Validation Loss: 0.2594, Dice: 0.8922, IoU: 0.8056, Precision: 0.8783, Recall: 0.9067, Accuracy: 0.8768
# Epoch 86/150, Loss: 0.0593, Dice: 0.8983, IoU: 0.8154, Precision: 0.8820, Recall: 0.9153, Accuracy: 0.8862
# Validation Loss: 0.2601, Dice: 0.8924, IoU: 0.8059, Precision: 0.8757, Recall: 0.9099, Accuracy: 0.8766
# Epoch 87/150, Loss: 0.0593, Dice: 0.8984, IoU: 0.8155, Precision: 0.8803, Recall: 0.9174, Accuracy: 0.8859
# Validation Loss: 0.2651, Dice: 0.8870, IoU: 0.7972, Precision: 0.8857, Recall: 0.8886, Accuracy: 0.8730
# Epoch 88/150, Loss: 0.0591, Dice: 0.8985, IoU: 0.8157, Precision: 0.8840, Recall: 0.9136, Accuracy: 0.8866
# Validation Loss: 0.2611, Dice: 0.8891, IoU: 0.8006, Precision: 0.8813, Recall: 0.8972, Accuracy: 0.8743
# Epoch 89/150, Loss: 0.0592, Dice: 0.8982, IoU: 0.8152, Precision: 0.8826, Recall: 0.9144, Accuracy: 0.8861
# Validation Loss: 0.2582, Dice: 0.8919, IoU: 0.8050, Precision: 0.8805, Recall: 0.9036, Accuracy: 0.8768
# Epoch 90/150, Loss: 0.0589, Dice: 0.8991, IoU: 0.8166, Precision: 0.8821, Recall: 0.9167, Accuracy: 0.8868
# Validation Loss: 0.2626, Dice: 0.8889, IoU: 0.8003, Precision: 0.8817, Recall: 0.8962, Accuracy: 0.8741
# Epoch 91/150, Loss: 0.0591, Dice: 0.8986, IoU: 0.8159, Precision: 0.8817, Recall: 0.9162, Accuracy: 0.8865
# Validation Loss: 0.2661, Dice: 0.8888, IoU: 0.8000, Precision: 0.8725, Recall: 0.9057, Accuracy: 0.8725
# Epoch 92/150, Loss: 0.0593, Dice: 0.8982, IoU: 0.8151, Precision: 0.8826, Recall: 0.9144, Accuracy: 0.8861
# Validation Loss: 0.2612, Dice: 0.8922, IoU: 0.8055, Precision: 0.8742, Recall: 0.9110, Accuracy: 0.8761
# Epoch 93/150, Loss: 0.0593, Dice: 0.8986, IoU: 0.8160, Precision: 0.8814, Recall: 0.9168, Accuracy: 0.8862
# Validation Loss: 0.2616, Dice: 0.8909, IoU: 0.8033, Precision: 0.8729, Recall: 0.9097, Accuracy: 0.8745
# Epoch 94/150, Loss: 0.0593, Dice: 0.8984, IoU: 0.8156, Precision: 0.8817, Recall: 0.9160, Accuracy: 0.8861
# Validation Loss: 0.2660, Dice: 0.8901, IoU: 0.8022, Precision: 0.8647, Recall: 0.9171, Accuracy: 0.8726
# Epoch 95/150, Loss: 0.0590, Dice: 0.8988, IoU: 0.8163, Precision: 0.8811, Recall: 0.9174, Accuracy: 0.8866
# Validation Loss: 0.2611, Dice: 0.8919, IoU: 0.8051, Precision: 0.8733, Recall: 0.9114, Accuracy: 0.8758
# Epoch 96/150, Loss: 0.0589, Dice: 0.8990, IoU: 0.8165, Precision: 0.8827, Recall: 0.9160, Accuracy: 0.8869
# Validation Loss: 0.2622, Dice: 0.8908, IoU: 0.8033, Precision: 0.8728, Recall: 0.9095, Accuracy: 0.8746
# Epoch 97/150, Loss: 0.0589, Dice: 0.8993, IoU: 0.8170, Precision: 0.8815, Recall: 0.9179, Accuracy: 0.8870
# Validation Loss: 0.2599, Dice: 0.8912, IoU: 0.8038, Precision: 0.8830, Recall: 0.8995, Accuracy: 0.8764
# Epoch 98/150, Loss: 0.0587, Dice: 0.8993, IoU: 0.8170, Precision: 0.8837, Recall: 0.9155, Accuracy: 0.8873
# Validation Loss: 0.2643, Dice: 0.8894, IoU: 0.8010, Precision: 0.8747, Recall: 0.9045, Accuracy: 0.8736
# Epoch 99/150, Loss: 0.0588, Dice: 0.8992, IoU: 0.8169, Precision: 0.8816, Recall: 0.9176, Accuracy: 0.8871
# Validation Loss: 0.2623, Dice: 0.8889, IoU: 0.8002, Precision: 0.8786, Recall: 0.8995, Accuracy: 0.8737
# Epoch 100/150, Loss: 0.0593, Dice: 0.8981, IoU: 0.8151, Precision: 0.8836, Recall: 0.9134, Accuracy: 0.8862
# Validation Loss: 0.2679, Dice: 0.8863, IoU: 0.7962, Precision: 0.8840, Recall: 0.8888, Accuracy: 0.8720
# Epoch 101/150, Loss: 0.0591, Dice: 0.8987, IoU: 0.8160, Precision: 0.8817, Recall: 0.9164, Accuracy: 0.8865
# Validation Loss: 0.2634, Dice: 0.8904, IoU: 0.8026, Precision: 0.8693, Recall: 0.9126, Accuracy: 0.8736
# Epoch 102/150, Loss: 0.0590, Dice: 0.8991, IoU: 0.8167, Precision: 0.8822, Recall: 0.9167, Accuracy: 0.8869
# Validation Loss: 0.2618, Dice: 0.8920, IoU: 0.8052, Precision: 0.8689, Recall: 0.9164, Accuracy: 0.8752
# Epoch 103/150, Loss: 0.0587, Dice: 0.8995, IoU: 0.8173, Precision: 0.8828, Recall: 0.9169, Accuracy: 0.8873
# Validation Loss: 0.2593, Dice: 0.8925, IoU: 0.8059, Precision: 0.8758, Recall: 0.9098, Accuracy: 0.8766
# Epoch 104/150, Loss: 0.0586, Dice: 0.8996, IoU: 0.8176, Precision: 0.8817, Recall: 0.9184, Accuracy: 0.8875
# Validation Loss: 0.2641, Dice: 0.8894, IoU: 0.8010, Precision: 0.8837, Recall: 0.8953, Accuracy: 0.8748
# Epoch 105/150, Loss: 0.0588, Dice: 0.8992, IoU: 0.8169, Precision: 0.8829, Recall: 0.9163, Accuracy: 0.8871
# Validation Loss: 0.2614, Dice: 0.8908, IoU: 0.8032, Precision: 0.8692, Recall: 0.9135, Accuracy: 0.8740
# Epoch 106/150, Loss: 0.0583, Dice: 0.8998, IoU: 0.8178, Precision: 0.8842, Recall: 0.9160, Accuracy: 0.8879
# Validation Loss: 0.2572, Dice: 0.8926, IoU: 0.8062, Precision: 0.8738, Recall: 0.9122, Accuracy: 0.8765
# Epoch 107/150, Loss: 0.0583, Dice: 0.9001, IoU: 0.8183, Precision: 0.8842, Recall: 0.9165, Accuracy: 0.8880
# Validation Loss: 0.2650, Dice: 0.8881, IoU: 0.7990, Precision: 0.8849, Recall: 0.8914, Accuracy: 0.8738
# Epoch 108/150, Loss: 0.0586, Dice: 0.8992, IoU: 0.8169, Precision: 0.8848, Recall: 0.9145, Accuracy: 0.8875
# Validation Loss: 0.2652, Dice: 0.8902, IoU: 0.8024, Precision: 0.8660, Recall: 0.9158, Accuracy: 0.8730
# Epoch 109/150, Loss: 0.0587, Dice: 0.8994, IoU: 0.8173, Precision: 0.8806, Recall: 0.9192, Accuracy: 0.8872
# Validation Loss: 0.2620, Dice: 0.8911, IoU: 0.8037, Precision: 0.8729, Recall: 0.9101, Accuracy: 0.8750
# Epoch 110/150, Loss: 0.0581, Dice: 0.9003, IoU: 0.8187, Precision: 0.8843, Recall: 0.9170, Accuracy: 0.8884
# Validation Loss: 0.2620, Dice: 0.8908, IoU: 0.8033, Precision: 0.8744, Recall: 0.9078, Accuracy: 0.8748
# Epoch 111/150, Loss: 0.0584, Dice: 0.8999, IoU: 0.8180, Precision: 0.8833, Recall: 0.9171, Accuracy: 0.8878
# Validation Loss: 0.2602, Dice: 0.8919, IoU: 0.8050, Precision: 0.8728, Recall: 0.9118, Accuracy: 0.8756
# Epoch 112/150, Loss: 0.0582, Dice: 0.9003, IoU: 0.8187, Precision: 0.8844, Recall: 0.9168, Accuracy: 0.8884
# Validation Loss: 0.2636, Dice: 0.8877, IoU: 0.7982, Precision: 0.8921, Recall: 0.8834, Accuracy: 0.8744
# Epoch 113/150, Loss: 0.0581, Dice: 0.9005, IoU: 0.8190, Precision: 0.8835, Recall: 0.9181, Accuracy: 0.8884
# Validation Loss: 0.2645, Dice: 0.8873, IoU: 0.7977, Precision: 0.8838, Recall: 0.8910, Accuracy: 0.8728
# Epoch 114/150, Loss: 0.0585, Dice: 0.8995, IoU: 0.8174, Precision: 0.8856, Recall: 0.9140, Accuracy: 0.8878
# Validation Loss: 0.2645, Dice: 0.8878, IoU: 0.7985, Precision: 0.8863, Recall: 0.8895, Accuracy: 0.8737
# Epoch 115/150, Loss: 0.0582, Dice: 0.9003, IoU: 0.8186, Precision: 0.8828, Recall: 0.9185, Accuracy: 0.8882
# Validation Loss: 0.2655, Dice: 0.8864, IoU: 0.7963, Precision: 0.8874, Recall: 0.8857, Accuracy: 0.8726
# Epoch 116/150, Loss: 0.0581, Dice: 0.9004, IoU: 0.8188, Precision: 0.8847, Recall: 0.9167, Accuracy: 0.8885
# Validation Loss: 0.2610, Dice: 0.8893, IoU: 0.8009, Precision: 0.8881, Recall: 0.8905, Accuracy: 0.8753
# Epoch 117/150, Loss: 0.0579, Dice: 0.9006, IoU: 0.8192, Precision: 0.8846, Recall: 0.9172, Accuracy: 0.8887
# Validation Loss: 0.2598, Dice: 0.8912, IoU: 0.8040, Precision: 0.8726, Recall: 0.9107, Accuracy: 0.8750
# Epoch 118/150, Loss: 0.0581, Dice: 0.9003, IoU: 0.8186, Precision: 0.8848, Recall: 0.9164, Accuracy: 0.8884
# Validation Loss: 0.2589, Dice: 0.8917, IoU: 0.8046, Precision: 0.8727, Recall: 0.9116, Accuracy: 0.8754
# Epoch 119/150, Loss: 0.0578, Dice: 0.9006, IoU: 0.8192, Precision: 0.8855, Recall: 0.9163, Accuracy: 0.8890
# Validation Loss: 0.2608, Dice: 0.8916, IoU: 0.8045, Precision: 0.8723, Recall: 0.9118, Accuracy: 0.8752
# Epoch 120/150, Loss: 0.0577, Dice: 0.9010, IoU: 0.8198, Precision: 0.8835, Recall: 0.9192, Accuracy: 0.8891
# Validation Loss: 0.2636, Dice: 0.8890, IoU: 0.8004, Precision: 0.8847, Recall: 0.8934, Accuracy: 0.8746
# Epoch 121/150, Loss: 0.0577, Dice: 0.9008, IoU: 0.8196, Precision: 0.8853, Recall: 0.9170, Accuracy: 0.8891
# Validation Loss: 0.2646, Dice: 0.8902, IoU: 0.8023, Precision: 0.8791, Recall: 0.9017, Accuracy: 0.8749
# Epoch 122/150, Loss: 0.0582, Dice: 0.9001, IoU: 0.8184, Precision: 0.8847, Recall: 0.9162, Accuracy: 0.8883
# Validation Loss: 0.2699, Dice: 0.8888, IoU: 0.8001, Precision: 0.8627, Recall: 0.9166, Accuracy: 0.8711
# Epoch 123/150, Loss: 0.0581, Dice: 0.9007, IoU: 0.8193, Precision: 0.8831, Recall: 0.9190, Accuracy: 0.8886
# Validation Loss: 0.2614, Dice: 0.8900, IoU: 0.8020, Precision: 0.8816, Recall: 0.8986, Accuracy: 0.8751
# Epoch 124/150, Loss: 0.0579, Dice: 0.9008, IoU: 0.8194, Precision: 0.8837, Recall: 0.9185, Accuracy: 0.8887
# Validation Loss: 0.2641, Dice: 0.8900, IoU: 0.8020, Precision: 0.8736, Recall: 0.9070, Accuracy: 0.8739
# Epoch 125/150, Loss: 0.0578, Dice: 0.9007, IoU: 0.8193, Precision: 0.8862, Recall: 0.9157, Accuracy: 0.8890
# Validation Loss: 0.2651, Dice: 0.8873, IoU: 0.7977, Precision: 0.8827, Recall: 0.8920, Accuracy: 0.8728
# Epoch 126/150, Loss: 0.0578, Dice: 0.9012, IoU: 0.8201, Precision: 0.8832, Recall: 0.9200, Accuracy: 0.8891
# Validation Loss: 0.2638, Dice: 0.8911, IoU: 0.8037, Precision: 0.8642, Recall: 0.9197, Accuracy: 0.8735
# Epoch 127/150, Loss: 0.0581, Dice: 0.9002, IoU: 0.8185, Precision: 0.8870, Recall: 0.9139, Accuracy: 0.8887
# Validation Loss: 0.2649, Dice: 0.8894, IoU: 0.8011, Precision: 0.8686, Recall: 0.9113, Accuracy: 0.8727
# Epoch 128/150, Loss: 0.0580, Dice: 0.9008, IoU: 0.8194, Precision: 0.8828, Recall: 0.9196, Accuracy: 0.8886
# Validation Loss: 0.2620, Dice: 0.8894, IoU: 0.8011, Precision: 0.8848, Recall: 0.8942, Accuracy: 0.8751
# Epoch 129/150, Loss: 0.0576, Dice: 0.9012, IoU: 0.8201, Precision: 0.8857, Recall: 0.9172, Accuracy: 0.8895
# Validation Loss: 0.2640, Dice: 0.8885, IoU: 0.7995, Precision: 0.8846, Recall: 0.8923, Accuracy: 0.8740
# Epoch 130/150, Loss: 0.0575, Dice: 0.9013, IoU: 0.8204, Precision: 0.8850, Recall: 0.9184, Accuracy: 0.8896
# Validation Loss: 0.2672, Dice: 0.8867, IoU: 0.7967, Precision: 0.8848, Recall: 0.8887, Accuracy: 0.8723
# Epoch 131/150, Loss: 0.0576, Dice: 0.9011, IoU: 0.8201, Precision: 0.8870, Recall: 0.9158, Accuracy: 0.8896
# Validation Loss: 0.2611, Dice: 0.8905, IoU: 0.8029, Precision: 0.8777, Recall: 0.9038, Accuracy: 0.8751
# Epoch 132/150, Loss: 0.0574, Dice: 0.9015, IoU: 0.8207, Precision: 0.8862, Recall: 0.9174, Accuracy: 0.8898
# Validation Loss: 0.2641, Dice: 0.8884, IoU: 0.7994, Precision: 0.8822, Recall: 0.8948, Accuracy: 0.8737
# Epoch 133/150, Loss: 0.0571, Dice: 0.9020, IoU: 0.8215, Precision: 0.8841, Recall: 0.9206, Accuracy: 0.8901
# Validation Loss: 0.2643, Dice: 0.8877, IoU: 0.7984, Precision: 0.8848, Recall: 0.8908, Accuracy: 0.8734
# Epoch 134/150, Loss: 0.0569, Dice: 0.9021, IoU: 0.8216, Precision: 0.8868, Recall: 0.9179, Accuracy: 0.8906
# Validation Loss: 0.2628, Dice: 0.8891, IoU: 0.8004, Precision: 0.8812, Recall: 0.8971, Accuracy: 0.8741
# Epoch 135/150, Loss: 0.0572, Dice: 0.9019, IoU: 0.8213, Precision: 0.8862, Recall: 0.9182, Accuracy: 0.8902
# Validation Loss: 0.2666, Dice: 0.8891, IoU: 0.8006, Precision: 0.8716, Recall: 0.9073, Accuracy: 0.8728
# Epoch 136/150, Loss: 0.0575, Dice: 0.9016, IoU: 0.8209, Precision: 0.8851, Recall: 0.9188, Accuracy: 0.8899
# Validation Loss: 0.2620, Dice: 0.8909, IoU: 0.8035, Precision: 0.8701, Recall: 0.9128, Accuracy: 0.8743
# Epoch 137/150, Loss: 0.0574, Dice: 0.9016, IoU: 0.8208, Precision: 0.8839, Recall: 0.9201, Accuracy: 0.8897
# Validation Loss: 0.2645, Dice: 0.8874, IoU: 0.7977, Precision: 0.8869, Recall: 0.8879, Accuracy: 0.8733
# Epoch 138/150, Loss: 0.0570, Dice: 0.9023, IoU: 0.8220, Precision: 0.8847, Recall: 0.9207, Accuracy: 0.8904
# Validation Loss: 0.2637, Dice: 0.8895, IoU: 0.8012, Precision: 0.8829, Recall: 0.8962, Accuracy: 0.8748
# Epoch 139/150, Loss: 0.0566, Dice: 0.9028, IoU: 0.8228, Precision: 0.8872, Recall: 0.9189, Accuracy: 0.8913
# Validation Loss: 0.2631, Dice: 0.8901, IoU: 0.8021, Precision: 0.8745, Recall: 0.9062, Accuracy: 0.8741
# Epoch 140/150, Loss: 0.0570, Dice: 0.9022, IoU: 0.8218, Precision: 0.8875, Recall: 0.9174, Accuracy: 0.8907
# Validation Loss: 0.2687, Dice: 0.8875, IoU: 0.7979, Precision: 0.8795, Recall: 0.8956, Accuracy: 0.8722
# Epoch 141/150, Loss: 0.0572, Dice: 0.9021, IoU: 0.8216, Precision: 0.8849, Recall: 0.9200, Accuracy: 0.8901
# Validation Loss: 0.2690, Dice: 0.8857, IoU: 0.7952, Precision: 0.8900, Recall: 0.8817, Accuracy: 0.8723
# Epoch 142/150, Loss: 0.0569, Dice: 0.9024, IoU: 0.8222, Precision: 0.8865, Recall: 0.9191, Accuracy: 0.8907
# Validation Loss: 0.2627, Dice: 0.8914, IoU: 0.8042, Precision: 0.8677, Recall: 0.9164, Accuracy: 0.8744
# Epoch 143/150, Loss: 0.0569, Dice: 0.9024, IoU: 0.8221, Precision: 0.8854, Recall: 0.9202, Accuracy: 0.8906
# Validation Loss: 0.2712, Dice: 0.8875, IoU: 0.7981, Precision: 0.8745, Recall: 0.9010, Accuracy: 0.8716
# Epoch 144/150, Loss: 0.0572, Dice: 0.9020, IoU: 0.8215, Precision: 0.8839, Recall: 0.9211, Accuracy: 0.8901
# Validation Loss: 0.2664, Dice: 0.8890, IoU: 0.8004, Precision: 0.8673, Recall: 0.9118, Accuracy: 0.8720
# Epoch 145/150, Loss: 0.0566, Dice: 0.9031, IoU: 0.8234, Precision: 0.8867, Recall: 0.9201, Accuracy: 0.8914
# Validation Loss: 0.2654, Dice: 0.8890, IoU: 0.8003, Precision: 0.8706, Recall: 0.9081, Accuracy: 0.8724
# Epoch 146/150, Loss: 0.0565, Dice: 0.9031, IoU: 0.8234, Precision: 0.8860, Recall: 0.9210, Accuracy: 0.8915
# Validation Loss: 0.2615, Dice: 0.8899, IoU: 0.8018, Precision: 0.8816, Recall: 0.8983, Accuracy: 0.8749
# Epoch 147/150, Loss: 0.0566, Dice: 0.9029, IoU: 0.8229, Precision: 0.8857, Recall: 0.9208, Accuracy: 0.8912
# Validation Loss: 0.2689, Dice: 0.8861, IoU: 0.7957, Precision: 0.8796, Recall: 0.8927, Accuracy: 0.8710
# Epoch 148/150, Loss: 0.0565, Dice: 0.9030, IoU: 0.8232, Precision: 0.8873, Recall: 0.9193, Accuracy: 0.8916
# Validation Loss: 0.2638, Dice: 0.8892, IoU: 0.8007, Precision: 0.8735, Recall: 0.9054, Accuracy: 0.8731
# Epoch 149/150, Loss: 0.0563, Dice: 0.9035, IoU: 0.8240, Precision: 0.8867, Recall: 0.9210, Accuracy: 0.8919
# Validation Loss: 0.2646, Dice: 0.8900, IoU: 0.8020, Precision: 0.8735, Recall: 0.9071, Accuracy: 0.8740
# Epoch 150/150, Loss: 0.0560, Dice: 0.9040, IoU: 0.8248, Precision: 0.8879, Recall: 0.9207, Accuracy: 0.8925
# Validation Loss: 0.2660, Dice: 0.8885, IoU: 0.7996, Precision: 0.8867, Recall: 0.8905, Accuracy: 0.8744
# 开始测试...
# Test Loss: 0.2548, IoU: 0.8099, Dice: 0.8950, Accuracy: 0.8790, Precision: 0.8889, Recall: 0.9012
# /tmp/ipykernel_2374169/218735646.py:350: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# Image Data Shape: (630, 519)
